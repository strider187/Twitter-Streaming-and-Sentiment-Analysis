# %%
#For Streaming data

# %%
import tweepy
from tweepy import API 
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
 
import twitter_credentials

# %%
# # # # TWITTER CLIENT # # # #
class TwitterClient():
    def __init__(self, twitter_user=None):
        self.auth = TwitterAuthenticator().authenticate_twitter_app()
        self.twitter_client = API(self.auth)

        self.twitter_user = twitter_user

    def get_user_timeline_tweets(self, num_tweets):
        tweets = []
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets

    def get_friend_list(self, num_friends):
        friend_list = []
        for friend in Cursor(self.twitter_client.friends, id=self.twitter_user).items(num_friends):
            friend_list.append(friend)
        return friend_list

    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets = []
        for tweet in Cursor(self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets

# %%
# # # # TWITTER AUTHENTICATER # # # #
class TwitterAuthenticator():

    def authenticate_twitter_app(self):
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
        auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
        return auth

# %%
# # # # TWITTER STREAMER # # # #
class TwitterStreamer():
    """
    Class for streaming and processing live tweets.
    """
    def __init__(self):
        self.twitter_autenticator = TwitterAuthenticator()    

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        # This handles Twitter authetification and the connection to Twitter Streaming API
        listener = TwitterListener(fetched_tweets_filename)
        auth = self.twitter_autenticator.authenticate_twitter_app() 
        stream = Stream(auth, listener)

        # This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=hash_tag_list)

# %%
# # # # TWITTER STREAM LISTENER # # # #
class TwitterListener(StreamListener):
    """
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
          
    def on_error(self, status):
        if status == 420:
            # Returning False on_data method in case rate limit occurs.
            return False
        print(status)

# %%
if __name__ == '__main__':
 
    # Authenticate using config.py and connect to Twitter Streaming API.
    hash_tag_list = ["Python", "JavaScript", "Ruby"]
    fetched_tweets_filename = "tweets_json.json"

    twitter_client = TwitterClient('vishu_tyagi_')
    print(twitter_client.get_user_timeline_tweets(1))

    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000016073B07A20>, _json={'created_at': 'Fri May 01 12:32:01 +0000 2020', 'id': 1256199698727272449, 'id_str': '1256199698727272449', 'text': '@airindiain I booked two tickets from Delhi to San Francisco for Tuesday, June 2 (PNR JYVGD). Considering the prese… https://t.co/V4Lcegam94', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'airindiain', 'name': 'Air India', 'id': 387573617, 'id_str': '387573617', 'indices': [0, 11]}], 'urls': [{'url': 'https://t.co/V4Lcegam94', 'expanded_url': 'https://twitter.com/i/web/status/1256199698727272449', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 387573617, 'in_reply_to_user_id_str': '387573617', 'in_reply_to_screen_name': 'airindiain', 'user': {'id': 1215638787272757248, 'id_str': '1215638787272757248', 'name': 'Vishu Tyagi', 'screen_name': 'vishu_tyagi_', 'location': '', 'description': "Curious. Thoughtful. Exhausted. Coder.\nI'm whatever they need me to be", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Fri Jan 10 14:17:44 +0000 2020', 'favourites_count': 159, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 21, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1220330020377223168/ekr0SiHU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220330020377223168/ekr0SiHU_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 5, 1, 12, 32, 1), id=1256199698727272449, id_str='1256199698727272449', text='@airindiain I booked two tickets from Delhi to San Francisco for Tuesday, June 2 (PNR JYVGD). Considering the prese… https://t.co/V4Lcegam94', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'airindiain', 'name': 'Air India', 'id': 387573617, 'id_str': '387573617', 'indices': [0, 11]}], 'urls': [{'url': 'https://t.co/V4Lcegam94', 'expanded_url': 'https://twitter.com/i/web/status/1256199698727272449', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=387573617, in_reply_to_user_id_str='387573617', in_reply_to_screen_name='airindiain', author=User(_api=<tweepy.api.API object at 0x0000016073B07A20>, _json={'id': 1215638787272757248, 'id_str': '1215638787272757248', 'name': 'Vishu Tyagi', 'screen_name': 'vishu_tyagi_', 'location': '', 'description': "Curious. Thoughtful. Exhausted. Coder.\nI'm whatever they need me to be", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Fri Jan 10 14:17:44 +0000 2020', 'favourites_count': 159, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, ...
# {"created_at":"Sat May 02 18:43:16 +0000 2020","id":1256655514227798016,"id_str":"1256655514227798016","text":"RT @javarevisited: Top 10 Free TypeScript Courses to Learn Online\u200a\u2014\u200aBest of Lot by @javinpaul https:\/\/t.co\/lO89KL36RJ #TypeScript #javascri\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":125107613,"id_str":"125107613","name":"sunnyesquire","screen_name":"sunny_esquire","location":null,"url":null,"description":"Shunya,  Retweets are not personal endorsements.","translator_type":"none","protected":false,"verified":false,"followers_count":181,"friends_count":333,"listed_count":8,"favourites_count":16511,"statuses_count":9982,"created_at":"Sun Mar 21 18:24:18 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/abs.twimg.com\/sticky\/default_profile_images\/default_profile_normal.png","profile_image_url_https":"https:\/\/abs.twimg.com\/sticky\/default_profile_images\/default_profile_normal.png","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Sat May 02 11:01:16 +0000 2020","id":1256539247797927936,"id_str":"1256539247797927936","text":"Top 10 Free TypeScript Courses to Learn Online\u200a\u2014\u200aBest of Lot by @javinpaul https:\/\/t.co\/lO89KL36RJ #TypeScript #javascript","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1005111468595920897,"id_str":"1005111468595920897","name":"Javarevisited","screen_name":"javarevisited","location":null,"url":"https:\/\/javarevisited.blogspot.com","description":"#Javarevisited is a @Java blog & @Medium pub http:\/\/medium.com\/javarevisited\/ Follow to learn #Java #Algorithms #Programming #DataStructure #SpringFramework","translator_type":"none","protected":false,"verified":false,"followers_count":9938,"friends_count":195,"listed_count":126,"favourites_count":6949,"statuses_count":7506,"created_at":"Fri Jun 08 15:37:02 +0000 2018","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1005114073116098560\/7rA9Pf6q_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1005114073116098560\/7rA9Pf6q_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":6,"favorite_count":14,"entities":{"hashtags":[{"text":"TypeScript","ind ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1520         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1521             raise WantReadError()
#    1522         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-60eafa34b1ed> in <module>()
#       9
#      10     twitter_streamer = TwitterStreamer()
# ---> 11     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#
# <ipython-input-151-f4093e85e2da> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      14
#      15         # This line filter Twitter Streams to capture data by the keywords:
# ---> 16         stream.filter(track=hash_tag_list)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
import json
import pandas as pd
import re
import numpy as np

# %%
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

# %%
#Sentimental Analysis from here onwards

# %%
auth = tweepy.OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
def list_tweets(user_id, count, prt=False):
    tweets = api.user_timeline(
        "@" + user_id, count=count, tweet_mode='extended')
    tw = []
    for t in tweets:
        tw.append(t.full_text)
        if prt:
            print(t.full_text)
            print()
    return tw

# %%
user_id = "realDonaldTrump"
count=200
tw_trump = list_tweets(user_id, count)

# %%
print(len(tw_trump))
# Out:
# 199

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    #print(r)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
    #print (input_txt)
    return input_txt
def clean_tweets(lst):
    # remove twitter Return handles (RT @xxx:)
    lst = np.vectorize(remove_pattern)(lst, "RT @[\w]*:")
    # remove twitter handles (@xxx)
    lst = np.vectorize(remove_pattern)(lst, "@[\w]*")
    # remove URL links (httpxxx)
    print("before++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print(lst)
    lst = np.vectorize(remove_pattern)(lst, "https?://[A-Za-z0-9./]*")
    print("After_______________________________________________________________________________________________________________")
    print(lst)
    #lst = re.sub(r"http\S+", "", lst)
    #clean_tweet = re.match('(.*?)http.*?\s?(.*?)', lst)
    #if clean_tweet: 
        #lst = clean_tweet.group(1)
        #lst = clean_tweet.group(2) # will print everything after the URL 
    # remove special characters, numbers, punctuations (except for #)
    lst = np.core.defchararray.replace(lst, "[^a-zA-Z#]", " ")
    return lst

# %%
clean_tw = []
clean_tw = clean_tweets(tw_trump)
# Out:
# before++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ['Thank you Michael. You also! https://t.co/VFi6Nhj3zG'
#  ' The FBI found "no derogatory information" about . But they decided to crush him anyway.\n\n"There is nothing worse…'
#  'The Russia Hoax is the biggest political scandal in American history. Treason!!! Lets see how it ends???? https://t.co/VRsVdiQrsf'
#  ' Join me for a quick laugh about the funniest Trump kill shot on Biden. Ever.🤣🤣🤣🤣🤣🤣 https://t.co/xn6U5w5iZe'
#  ' This kill shot is so perfectly executed it is painful to watch . . . and still funny. 🤣🤣🤣'
#  ' Poll for Democrats only. Are you aware that most of the political news you consume is either misleading and out of cont…'
#  " Greg Gutfeld on Biden response to Tara Reade claims: He 'was doing great in that interview until he confessed' https://…"
#  "  It's an absolute disgrace what they've done to  and his family.\n\nThis is one of the most highly…"
#  "   Why does MSM ignore this???\n\nWhy do people ignore that he doesn't care about the #American worker…"
#  '  Sleepy Joe fell asleep during his last town hall! https://t.co/PTAdesPUk5'
#  'Thank you! https://t.co/LSGA6Tg0zk'
#  "  At this rate, if you don't support Trump and you're a Republican you've gone entirely mad."
#  "  All of the Democrats stick together, that's a lesson that the Republican party needs to learn, support…"
#  'I have done more for farmers and ranchers than any President in history, and it has been my honor in doing so! '
#  ' President  is using the Defense Production Act to ensure that Americans have a reliable supply of beef, por…'
#  ' Our supporters are working hard every day and getting the message out about ’s leadership. We’re going t…'
#  ' The always careful \u2066\u2069 is even more cautious here, but he and \u2066\u2069 are pointing in the same direction…'
#  ' The CCP’s Military-Civil Fusion strategy blurs the distinction between Chinese military &amp; civilian end-users. I commend t…'
#  ' Tremendous work by  \n\nWhile the rest of the media was credulous and lazy about this case, it dug in with real rep…'
#  " Something seems rotten in Flynn's case — my column  ... "
#  ' . is Ultimately Responsible for ’s Dirty Investigation into \n\n'
#  '“The only thing we got wrong is that it was even worse (the corruption) than we thought.”   DIRTY COPS!'
#  ' New DOJ/Flynn docs are stamped w SCO as in Special Counsels Office\n \nDid Mueller have these docs? Why did his team sit o…'
#  'Vote  by May 12th! His opponent  voted to fire teachers, and cut their salaries while bumping up her pay. Now she’s mocking our Great Vets! We need Navy Fighter Pilot Mike Garcia in #CA25! '
#  '....He is Strong on Crime, the Border, and Second Amendment. Tom has deep roots in Wisconsin, is a big Tax Cutter, and will help me DRAIN THE SWAMP! Tom has my Complete and Total Endorsement. Vote for Tom Tiffany! '
#  'Tom Tiffany () is a Great Advocate for the incredible people of Wisconsin (WI07). We need Tom in Congress to help us Make America Great Again! He will Fight for Small Business, supports our Incredible Farmers, Loves our Military and our Vets....'
#  " LIVE: POTUS Delivers Remarks on Protecting America's Seniors "
#  'Over 120 MILLION Economic Impact Payments have already gone out to hardworking Americans! If you haven’t yet received your payment, go to  and click on “GET MY PAYMENT” to receive your money FAST!'
#  ' President  just met with  on Coronavirus testing, financial assistance, and planning a great come…'
#  ' President : "We\'re working very hard with New Jersey." '
#  " We already knew that James Comey's FBI was out to get General Flynn and President Trump. \n\nBut it was worse than we thoug…"
#  'We can’t let the Fake News, and their partner, the Radical Left, Do Nothing Democrats, get away with stealing the Election. They tried that in 2016. How did that work out?'
#  ' Just announced: over $33 million in funding from the HHS has been released to #NY21 hospitals. I will continue to work to…'
#  ' Speaker Pelosi still refuses to consider any plan to allow the House to operate or function remotely. Sidelining and para…'
#  ' Safeguarding our nation’s food supply is a critical component necessary to defeat the spread of coronavirus. I support th…'
#  ' The Flynn documents are out. One line is as significant as it is shocking. Indeed, for those who have long seen a conce…'
#  ' What did FBI Director Christopher Wray know and when? And why has he been covering for these scum bags? …'
#  ' #FLYNN docs just unsealed, including handwritten notes 1/24/2017 day of Flynn FBI interview.  Transcript: “What is our go…'
#  ' . and I disagree on quite a bit and there are parts of his management of which I’ve been critical but I’m glad…'
#  ' Devastating flashback clip of Comey just aired on  show.\n\nWhen asked who went around the protocol of goi…'
#  ' If you care about liberty, freedom, or corruption at the highest levels of the government, you have to care about Gen.…'
#  ' ACQUITTED FOR LIFE. '
#  " Proud 2hear abt collaborative efforts in every sector of Iowa's economy Helping each other is the Iowa way Recent exampl…"
#  " Pres  is right 2use authority 2 keep open meat processing plants Its critical infrastructure 4 country's…"
#  'Many States moving to SAFELY &amp; QUICKLY reopen!'
#  'We are doing far more, and better, Testing than any other country in the world, and yet the media does nothing but complain. No matter how good a job is done, the same as with the Ventilators, they will never say we are doing a great job, they will only viciously gripe!'
#  ' First, there is no shortage of meat destined for the grocery store shelf. \n\nIt might take stores longer than usual to resto…'
#  ' '
#  ' Attorney General Barr’s Memo to U.S. Attorneys: \n\n“The Constitution is not suspended in times of crisis.” \n\nThe Attorney Ge…'
#  'Because Shifty is a crooked politician! '
#  ' FAKE NEWS, THE ENEMY OF THE PEOPLE!'
#  ' There has never been, in the history of our Country, a more vicious or hostile Lamestream Media than there is right no…'
#  ' Blame the Democrats for any “lateness” in your Enhanced Unemployment Insurance. I wanted the money to be paid directly…'
#  ' So true!'
#  " President 's plan for Opening Up America Again outlined a three-phased approach based on the advice of publ…"
#  ''
#  ' "We\'re doing everything in our power to heal the sick and to gradually reopen our Nation." '
#  ' As one American family, we grieve with those who have suffered the loss of loved ones. '
#  ' LIVE: President  holds a news conference '
#  'I will be having a White House Press Conference today at 5:30 P.M. Thank you!'
#  'Why should the people and taxpayers of America be bailing out poorly run states (like Illinois, as example) and cities, in all cases Democrat run and managed, when most of the other states are not looking for bailout help? I am open to discussing anything, but just asking?'
#  'FAKE NEWS, THE ENEMY OF THE PEOPLE!'
#  'There has never been, in the history of our Country, a more vicious or hostile Lamestream Media than there is right now, even in the midst of a National Emergency, the Invisible Enemy!'
#  'Blame the Democrats for any “lateness” in your Enhanced Unemployment Insurance. I wanted the money to be paid directly, they insisted it be paid by states for distribution. I told them this would happen, especially with many states which have old computers.'
#  'So true! '
#  ' I never said the pandemic was a Hoax! Who would say such a thing? I said that the Do Nothing Democrats, together with…'
#  ' The people that know me and know the history of our Country say that I am  the hardest working President in history. I…'
#  " Sloppy Joe is trending. I wonder if it's because of this. You can tell it's a deep fake because Jill Biden isn't covering f…"
#  ' Article should have read: Trump as businessman had a passive, non-controlling/managing interest in an office building which…'
#  ' Devin Nunes-“Why is General Flynn Important? Because He Was Framed By His Own Government!!” #HumanScum  …'
#  ' Despite Democrats resistance to help small businesses, President  will get the economy going and Americ…'
#  ' Lefty holier than thou Media Matters founder David Brock, who spends millions targeting President Trump, is accused of…'
#  ' Democrats are not sending us their best\n\nor are they😜'
#  ' Here’s what serial fraudster, &amp; generational corruptocrat, Nancy Pelosi was REALLY up to when the Wuhan Virus was raging &amp; th…'
#  ' Report: FBI Knew McCain Leaked Steele Dossier, Now Blames Coronavirus For Not Releasing Documents '
#  ' Former NSC Chief of Staff Says John Brennan Hid Evidence Putin Favored Hillary in 2016 🔥🔥🔥\n'
#  ' You’re a racist, radical communist that wants to expand government control and dependency— and you are using the plight o…'
#  ' Once again, Nancy Pelosi is lying about her needless delay.\n\nShe stood in front of her fancy refrigerator and congratula…'
#  ' Wishing you a very special birthday, . Happy Birthday! \U0001f973🎂'
#  'American citizens! We were long ahead of Dems, who were all against the BAN. '
#  " Three failed coup attempts:\n\n1 - Russia Collusion hoax during campaign\n2 - Mueller's sham \n3 - Illegitimate impeachment…"
#  ' Breaking News: sources tell me  will be completely exonerated this week.  It was a total fraud.  A Set up.  Mo…'
#  'Great! '
#  ' Dear God,\nThank you for answering our prayers.\nA grateful Nation\n\n#GodBlessAmerica🇺🇸 #PresidentTrump #ElectionDay …'
#  ' WATCH: Team Trump Online with , Rep. , and Rep. ! #TeamTrump\n\nText TRUMP to 88022 http…'
#  ' Remember, the Cure can’t be worse than the problem itself. Be careful, be safe, use common sense!'
#  ' From Day 1, Gretchen Whitmer has been too focused on politics.\n\nCase in point: She just claimed she is “not getting invo…'
#  'They are one of the worst in the “news” business. Total slime balls! '
#  'They asked me to be at West Point on June 13th., &amp; I will be there! '
#  ' "All of American society is engaged and mobilized in the war against the invisible enemy. While we must remain vigilant, it…'
#  ' We’re seeing enthusiasm like this all across the country. Thank you to all the  supporters who pitched i…']

# %%
#VaderSentiment for sentimental analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
sent = []
for t in clean_tw:
    sent.append(analyser.polarity_scores(t)['compound'])
    #print(analyser.polarity_scores(t))

# %%
sent
# Out:
# [0.4199,
#  -0.2263,
#  -0.8669,
#  0.9716,
#  0.8825,
#  -0.4019,
#  0.6249,
#  -0.4939,
#  -0.8002,
#  0.0,
#  0.4199,
#  -0.6957,
#  0.4019,
#  0.4019,
#  0.8268,
#  -0.0387,
#  0.0,
#  -0.296,
#  -0.296,
#  -0.3869,
#  -0.0258,
#  0.5719,
#  0.3818,
#  -0.0516,
#  0.0,
#  0.0,
#  0.5423,
#  0.5106,
#  0.0,
#  0.0,
#  0.0,
#  0.6459,
#  0.906,
#  0.3664,
#  0.8074,
#  0.2473,
#  -0.8111,
#  0.6476,
#  0.0,
#  0.2023,
#  -0.4926,
#  0.0,
#  0.5411,
#  0.4767,
#  0.3612,
#  -0.012,
#  0.4404,
#  -0.3612,
#  -0.5106,
#  -0.1531,
#  -0.8786,
#  0.4019,
#  -0.4168,
#  0.6885,
#  0.9439,
#  0.0,
#  0.0,
#  0.6249,
#  -0.1761,
#  -0.631,
#  -0.7783,
#  0.0,
#  0.2263,
#  -0.128,
#  -0.2263,
#  0.0,
#  0.0,
#  -0.3506,
#  -0.6486,
#  0.9325,
#  0.25,
#  0.6486,
#  -0.25,
#  0.5267,
#  0.0,
#  0.4588,
#  0.6597,
#  0.3612,
#  0.5859,
#  -0.4215,
#  -0.7777,
#  0.3612,
#  0.0,
#  0.0,
#  -0.73,
#  -0.5255,
#  0.6588,
#  -0.5706,
#  -0.4926,
#  0.4404,
#  0.6891,
#  0.0,
#  0.0,
#  -0.4767,
#  0.0,
#  -0.5707,
#  0.4391,
#  0.5267,
#  -0.6408,
#  0.0,
#  0.0,
#  0.0343,
#  -0.765,
#  0.0,
#  -0.7277,
#  0.4199,
#  -0.8858,
#  -0.2003,
#  0.0,
#  -0.819,
#  0.5848,
#  -0.4981,
#  -0.8676,
#  0.0,
#  0.0,
#  0.6114,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.2732,
#  0.3818,
#  0.4263,
#  0.4588,
#  0.6958,
#  0.5461,
#  0.3612,
#  0.089,
#  0.6696,
#  0.0,
#  0.3612,
#  0.3612,
#  -0.3612,
#  0.5574,
#  -0.7096,
#  -0.5707,
#  -0.128,
#  0.4926,
#  0.4199,
#  0.6696,
#  0.7351,
#  0.0,
#  0.0,
#  0.4404,
#  0.4199,
#  -0.5574,
#  0.0,
#  0.0,
#  0.6486,
#  0.8805,
#  0.1027,
#  0.6249,
#  0.6399,
#  0.9097,
#  0.1877,
#  0.0,
#  0.3724,
#  0.0,
#  -0.784,
#  -0.6865,
#  -0.6486,
#  0.5244,
#  0.0,
#  0.0,
#  -0.5106,
#  -0.4939,
#  0.0,
#  0.4199,
#  0.4781,
#  -0.784,
#  -0.9011,
#  -0.6486,
#  0.5244,
#  -0.3382,
#  0.0,
#  -0.4767,
#  0.5859,
#  0.3365,
#  0.4019,
#  -0.2732,
#  0.6369,
#  -0.7845,
#  -0.6124,
#  -0.5859,
#  -0.4019,
#  -0.6908,
#  0.8881,
#  -0.6833,
#  -0.6597,
#  -0.25,
#  0.6588,
#  0.8481,
#  0.0,
#  -0.3802,
#  0.3818,
#  -0.6588,
#  0.0,
#  -0.6124,
#  0.8689]

# %%
for (s, t) in zip(sent, clean_tw):
    print("Tweet is:")
    print(t)
    if(s < 0):
        print("negative")
    elif(s == 0):
        print("neutral")
    else:
        print("positive")
    print("-------------------------------------------------------------------------------------------------------------")
# Out:
# Tweet is:
# Thank you Michael. You also!
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  The FBI found "no derogatory information" about . But they decided to crush him anyway.
#
# "There is nothing worse…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# The Russia Hoax is the biggest political scandal in American history. Treason!!! Lets see how it ends????
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Join me for a quick laugh about the funniest Trump kill shot on Biden. Ever.🤣🤣🤣🤣🤣🤣
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  This kill shot is so perfectly executed it is painful to watch . . . and still funny. 🤣🤣🤣
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Poll for Democrats only. Are you aware that most of the political news you consume is either misleading and out of cont…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Greg Gutfeld on Biden response to Tara Reade claims: He 'was doing great in that interview until he confessed' …
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#   It's an absolute disgrace what they've done to  and his family.
#
# This is one of the most highly…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#    Why does MSM ignore this???
#
# Why do people ignore that he doesn't care about the #American worker…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#   Sleepy Joe fell asleep during his last town hall!
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# Thank you!
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#   At this rate, if you don't support Trump and you're a Republican you've gone entirely mad.
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#   All of the Democrats stick together, that's a lesson that the Republican party needs to learn, support…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#   As far as I am concerned, it should be a 100% approval from all of the Republican party, whats wrong wi…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# 96% Approval Rating in the Republican Party. Thank you! Also, just out, highest ever Approval Rating overall in the new Gallup Poll, and shows “Trump beating Sleepy Joe Biden.”
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# There is tremendous CoronaVirus testing capacity in Washington for the Senators returning to Capital Hill on Monday. Likewise the House, which should return but isn’t because of Crazy Nancy P. The 5 minute Abbott Test will be used. Please inform Dr. Brian P. Monahan.
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Stunning Silence:  says when it comes to sexual assault allegations against Joe Biden, it’s as if the “Me Too” mo…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  The FBI knew Michael Flynn wasn’t colluding with Russia, so it plotted to ‘get him to lie.’ New documents reveal that, by…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# Don’t allow RIGGED ELECTIONS!
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Thank you Dr. Lockwood and medical staff at  for your contributions and perspective on Florida‘s fight against…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Positivity rates for covid19 testing nationally are starting to decline as testing expands sharply and we move more te…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  If you must travel, take these steps to protect yourself &amp; others from #COVID19 during your trip.  https…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  A big win for patients and the first building block in what will be an improving toolbox for reducing death and diseas…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  President  honored several individuals today who have responded to this invisible enemy with courage, deter…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#

# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Breaking News: sources tell me  will be completely exonerated this week.  It was a total fraud.  A Set up.  Mo…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# Great!
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Dear God,
# Thank you for answering our prayers.
# A grateful Nation
#
# #GodBlessAmerica🇺🇸 #PresidentTrump #ElectionDay …
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  WATCH: Team Trump Online with , Rep. , and Rep. ! #TeamTrump
#
# Text TRUMP to 88022 http…
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  Remember, the Cure can’t be worse than the problem itself. Be careful, be safe, use common sense!
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  From Day 1, Gretchen Whitmer has been too focused on politics.
#
# Case in point: She just claimed she is “not getting invo…
# positive
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# They are one of the worst in the “news” business. Total slime balls!
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
# They asked me to be at West Point on June 13th., &amp; I will be there!
# neutral
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  "All of American society is engaged and mobilized in the war against the invisible enemy. While we must remain vigilant, it…
# negative
# -------------------------------------------------------------------------------------------------------------
# Tweet is:
#  We’re seeing enthusiasm like this all across the country. Thank you to all the  supporters who pitched i…
# positive
# -------------------------------------------------------------------------------------------------------------

# %%
from nltk.tokenize import TweetTokenizer

# %%
tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
#tockenizer example
for tweet in clean_tw:
    print (tweet_tokenizer.tokenize(tweet))
# Out:
# ['thank', 'you', 'michael', '.', 'you', 'also', '!']
# ['the', 'fbi', 'found', '"', 'no', 'derogatory', 'information', '"', 'about', '.', 'but', 'they', 'decided', 'to', 'crush', 'him', 'anyway', '.', '"', 'there', 'is', 'nothing', 'worse', '…']
# ['the', 'russia', 'hoax', 'is', 'the', 'biggest', 'political', 'scandal', 'in', 'american', 'history', '.', 'treason', '!', '!', '!', 'lets', 'see', 'how', 'it', 'ends', '?', '?', '?']
# ['join', 'me', 'for', 'a', 'quick', 'laugh', 'about', 'the', 'funniest', 'trump', 'kill', 'shot', 'on', 'biden', '.', 'ever', '.', '🤣', '🤣', '🤣']
# ['this', 'kill', 'shot', 'is', 'so', 'perfectly', 'executed', 'it', 'is', 'painful', 'to', 'watch', '. . .', 'and', 'still', 'funny', '.', '🤣', '🤣', '🤣']
# ['poll', 'for', 'democrats', 'only', '.', 'are', 'you', 'aware', 'that', 'most', 'of', 'the', 'political', 'news', 'you', 'consume', 'is', 'either', 'misleading', 'and', 'out', 'of', 'cont', '…']
# ['greg', 'gutfeld', 'on', 'biden', 'response', 'to', 'tara', 'reade', 'claims', ':', 'he', "'", 'was', 'doing', 'great', 'in', 'that', 'interview', 'until', 'he', 'confessed', "'", '…']
# ["it's", 'an', 'absolute', 'disgrace', 'what', "they've", 'done', 'to', 'and', 'his', 'family', '.', 'this', 'is', 'one', 'of', 'the', 'most', 'highly', '…']
# ['why', 'does', 'msm', 'ignore', 'this', '?', '?', '?', 'why', 'do', 'people', 'ignore', 'that', 'he', "doesn't", 'care', 'about', 'the', '#american', 'worker', '…']
# ['sleepy', 'joe', 'fell', 'asleep', 'during', 'his', 'last', 'town', 'hall', '!']
# ['thank', 'you', '!']
# ['at', 'this', 'rate', ',', 'if', 'you', "don't", 'support', 'trump', 'and', "you're", 'a', 'republican', "you've", 'gone', 'entirely', 'mad', '.']
# ['all', 'of', 'the', 'democrats', 'stick', 'together', ',', "that's", 'a', 'lesson', 'that', 'the', 'republican', 'party', 'needs', 'to', 'learn', ',', 'support', '…']
# ['as', 'far', 'as', 'i', 'am', 'concerned', ',', 'it', 'should', 'be', 'a', '100', '%', 'approval', 'from', 'all', 'of', 'the', 'republican', 'party', ',', 'whats', 'wrong', 'wi', '…']
# ['96', '%', 'approval', 'rating', 'in', 'the', 'republican', 'party', '.', 'thank', 'you', '!', 'also', ',', 'just', 'out', ',', 'highest', 'ever', 'approval', 'rating', 'overall', 'in', 'the', 'new', 'gallup', 'poll', ',', 'and', 'shows', '“', 'trump', 'beating', 'sleepy', 'joe', 'biden', '.', '”']
# ['there', 'is', 'tremendous', 'coronavirus', 'testing', 'capacity', 'in', 'washington', 'for', 'the', 'senators', 'returning', 'to', 'capital', 'hill', 'on', 'monday', '.', 'likewise', 'the', 'house', ',', 'which', 'should', 'return', 'but', 'isn', '’', 't', 'because', 'of', 'crazy', 'nancy', 'p', '.', 'the', '5', 'minute', 'abbott', 'test', 'will', 'be', 'used', '.', 'please', 'inform', 'dr', '.', 'brian', 'p', '.', 'monahan', '.']
# []
# ['stunning', 'silence', ':', 'says', 'when', 'it', 'comes', 'to', 'sexual', 'assault', 'allegations', 'against', 'joe', 'biden', ',', 'it', '’', 's', 'as', 'if', 'the', '“', 'me', 'too', '”', 'mo', '…']
# ['the', 'fbi', 'knew', 'michael', 'flynn', 'wasn', '’', 't', 'colluding', 'with', 'russia', ',', 'so', 'it', 'plotted', 'to', '‘', 'get', 'him', 'to', 'lie', '.', '’', 'new', 'documents', 'reveal', 'that', ',', 'by', '…']
# ['don', '’', 't', 'allow', 'rigged', 'elections', '!']
# ['thank', 'you', 'dr', '.', 'lockwood', 'and', 'medical', 'staff', 'at', 'for', 'your', 'contributions', 'and', 'perspective', 'on', 'florida', '‘', 's', 'fight', 'against', '…']
# ['positivity', 'rates', 'for', 'covid', '19', 'testing', 'nationally', 'are', 'starting', 'to', 'decline', 'as', 'testing', 'expands', 'sharply', 'and', 'we', 'move', 'more', 'te', '…']
# ['if', 'you', 'must', 'travel', ',', 'take', 'these', 'steps', 'to', 'protect', 'yourself', '&', 'others', 'from', '#covid19', 'during', 'your', 'trip', '.', 'https', '…']
# ['a', 'big', 'win', 'for', 'patients', 'and', 'the', 'first', 'building', 'block', 'in', 'what', 'will', 'be', 'an', 'improving', 'toolbox', 'for', 'reducing', 'death', 'and', 'diseas', '…']
# []
# []
# ['president', 'honored', 'several', 'individuals', 'today', 'who', 'have', 'responded', 'to', 'this', 'invisible', 'enemy', 'with', 'courage', ',', 'deter', '…']
# ['fdny', 'members', 'show', 'their', 'appreciation', 'for', '100', 'national', 'ambulance', 'contract', 'units', 'as', 'they', 'deploy', 'back', 'home', 'after', '30', 'days', 'spent', '…']
# ["tomorrow's", '#americastrong', 'flyover', 'serves', 'as', 'a', 'salute', 'to', 'frontline', '#covid', 'responders', '.', '#inthistogether', '🇺', '🇸', '…']
# ['live', ':', 'president', 'at', 'presidential', 'recognition', 'ceremony']
# []
# ['...', 'together', 'we', 'will', 'fight', 'for', 'small', 'businesses', 'and', 'protect', 'american', 'energy', 'workers', '!', 'shelley', 'has', 'my', 'complete', 'and', 'total', 'endorsement', '!']
# ['senator', 'shelley', 'moore', 'capito', '(', ')', 'is', 'doing', 'a', 'tremendous', 'job', 'for', 'the', 'great', 'people', 'of', 'west', 'virginia', '!', 'she', 'strongly', 'defends', 'our', 'second', 'amendment', ',', 'supports', 'our', 'veterans', 'and', 'is', 'strong', 'on', 'life', 'and', 'the', 'border', '...']
# ['concast', '(', ')', 'and', 'fake', 'news', 'are', 'going', 'out', 'of', 'their', 'way', 'to', 'say', 'great', 'things', 'about', 'china', '.', 'they', 'are', 'chinese', 'puppets', 'who', 'want', 'to', 'do', 'business', 'there', '.', 'they', 'use', 'usa', 'airwaves', 'to', 'help', 'china', '.', 'the', 'enemy', 'of', 'the', 'people', '!']
# ['trump', 'gets', 'bump', 'in', 'latest', 'gallup', 'poll', ':', '49', '%', 'approval', '(', '+', '6', ',', 'tied', 'for', 'his', 'best', ')', '47', '%', 'disapproval', '(', '-', '7', ')']
# ['the', 'governor', 'of', 'michigan', 'should', 'give', 'a', 'little', ',', 'and', 'put', 'out', 'the', 'fire', '.', 'these', 'are', 'very', 'good', 'people', ',', 'but', 'they', 'are', 'angry', '.', 'they', 'want', 'their', 'lives', 'back', 'again', ',', 'safely', '!', 'see', 'them', ',', 'talk', 'to', 'them', ',', 'make', 'a', 'deal', '.']
# ['cryin', 'chuck', 'schumer', ',', 'compared', 'to', 'what', 'other', 'senators', 'have', 'brought', 'home', 'to', 'their', 'states', ',', 'has', 'brought', 'very', 'little', 'back', 'to', 'n', '.', 'y', '.', 'a', 'totally', 'overrated', 'loser', ',', 'the', 'one', 'thing', 'he', 'has', 'given', 'them', 'is', 'salt', '.', 'he', 'never', 'even', 'called', 'me', 'to', 'stop', 'it', '.', 'no', 'wonder', 'cuomo', '&', 'most', 'others', 'can', '’', 't', 'stand', 'him', '.', 'aoc', '!']
# ['cryin', '’', 'chuck', 'schumer', 'was', 'on', 'a', 'late', 'night', 'show', 'using', 'a', 'false', 'talking', 'point', 'over', '&', 'over', 'again', '.', '“', 'we', 'don', '’', 't', 'have', 'enough', 'testing', ',', '”', 'he', 'would', 'repeat', ',', 'when', 'he', 'knows', 'we', 'have', 'done', 'a', 'great', 'job', 'on', 'testing', ',', 'just', 'like', 'we', 'have', 'on', 'ventilators', 'and', 'everything', 'else', '.', 'he', 'lied', ',', 'gave', 'ny', 'salt', '.', 'run', 'aoc', '!']
# ['president', ':', '“', 'we', '’', 've', 'spent', '8', 'trillion', 'dollars', 'in', 'the', 'middle', 'east', 'and', 'we', '’', 're', 'not', 'fixing', 'our', 'roads', '.', '”', '…']
# ['under', 'president', '’', 's', 'leadership', ',', 'we', 'gave', 'and', 'the', 'authority', 'under', 'the', 'defense', 'production', 'act', 'to', 'i', '…']
# ['dirty', 'cop', '!']
# ['since', 'the', 'first', 'days', 'of', 'this', 'pandemic', ',', 'president', 'has', 'brought', 'a', 'whole', 'of', 'america', 'response', '&', 'we', '’', 're', 'making', 'gr', '…']
# ['i', 'have', 'done', 'more', 'for', 'farmers', 'and', 'ranchers', 'than', 'any', 'president', 'in', 'history', ',', 'and', 'it', 'has', 'been', 'my', 'honor', 'in', 'doing', 'so', '!']
# ['president', 'is', 'using', 'the', 'defense', 'production', 'act', 'to', 'ensure', 'that', 'americans', 'have', 'a', 'reliable', 'supply', 'of', 'beef', ',', 'por', '…']
# ['our', 'supporters', 'are', 'working', 'hard', 'every', 'day', 'and', 'getting', 'the', 'message', 'out', 'about', '’', 's', 'leadership', '.', 'we', '’', 're', 'going', 't', '…']
# ['the', 'always', 'careful', '\u2066', '\u2069', 'is', 'even', 'more', 'cautious', 'here', ',', 'but', 'he', 'and', '\u2066', '\u2069', 'are', 'pointing', 'in', 'the', 'same', 'direction', '…']
# ['the', 'ccp', '’', 's', 'military-civil', 'fusion', 'strategy', 'blurs', 'the', 'distinction', 'between', 'chinese', 'military', '&', 'civilian', 'end-users', '.', 'i', 'commend', 't', '…']
# ['tremendous', 'work', 'by', 'while', 'the', 'rest', 'of', 'the', 'media', 'was', 'credulous', 'and', 'lazy', 'about', 'this', 'case', ',', 'it', 'dug', 'in', 'with', 'real', 'rep', '…']
# ['something', 'seems', 'rotten', 'in', "flynn's", 'case', '—', 'my', 'column', '...']
# ['.', 'is', 'ultimately', 'responsible', 'for', '’', 's', 'dirty', 'investigation', 'into']
# ['“', 'the', 'only', 'thing', 'we', 'got', 'wrong', 'is', 'that', 'it', 'was', 'even', 'worse', '(', 'the', 'corruption', ')', 'than', 'we', 'thought', '.', '”', 'dirty', 'cops', '!']
# ['new', 'doj', '/', 'flynn', 'docs', 'are', 'stamped', 'w', 'sco', 'as', 'in', 'special', 'counsels', 'office', 'did', 'mueller', 'have', 'these', 'docs', '?', 'why', 'did', 'his', 'team', 'sit', 'o', '…']
# ['vote', 'by', 'may', '12th', '!', 'his', 'opponent', 'voted', 'to', 'fire', 'teachers', ',', 'and', 'cut', 'their', 'salaries', 'while', 'bumping', 'up', 'her', 'pay', '.', 'now', 'she', '’', 's', 'mocking', 'our', 'great', 'vets', '!', 'we', 'need', 'navy', 'fighter', 'pilot', 'mike', 'garcia', 'in', '#ca25', '!']
# ['...', 'he', 'is', 'strong', 'on', 'crime', ',', 'the', 'border', ',', 'and', 'second', 'amendment', '.', 'tom', 'has', 'deep', 'roots', 'in', 'wisconsin', ',', 'is', 'a', 'big', 'tax', 'cutter', ',', 'and', 'will', 'help', 'me', 'drain', 'the', 'swamp', '!', 'tom', 'has', 'my', 'complete', 'and', 'total', 'endorsement', '.', 'vote', 'for', 'tom', 'tiffany', '!']
# ['tom', 'tiffany', '(', ')', 'is', 'a', 'great', 'advocate', 'for', 'the', 'incredible', 'people', 'of', 'wisconsin', '(', 'wi07', ')', '.', 'we', 'need', 'tom', 'in', 'congress', 'to', 'help', 'us', 'make', 'america', 'great', 'again', '!', 'he', 'will', 'fight', 'for', 'small', 'business', ',', 'supports', 'our', 'incredible', 'farmers', ',', 'loves', 'our', 'military', 'and', 'our', 'vets', '...']
# ['live', ':', 'potus', 'delivers', 'remarks', 'on', 'protecting', "america's", 'seniors']
# ['over', '120', 'million', 'economic', 'impact', 'payments', 'have', 'already', 'gone', 'out', 'to', 'hardworking', 'americans', '!', 'if', 'you', 'haven', '’', 't', 'yet', 'received', 'your', 'payment', ',', 'go', 'to', 'and', 'click', 'on', '“', 'get', 'my', 'payment', '”', 'to', 'receive', 'your', 'money', 'fast', '!']
# ['president', 'just', 'met', 'with', 'on', 'coronavirus', 'testing', ',', 'financial', 'assistance', ',', 'and', 'planning', 'a', 'great', 'come', '…']
# ['president', ':', '"', "we're", 'working', 'very', 'hard', 'with', 'new', 'jersey', '.', '"']
# ['we', 'already', 'knew', 'that', 'james', "comey's", 'fbi', 'was', 'out', 'to', 'get', 'general', 'flynn', 'and', 'president', 'trump', '.', 'but', 'it', 'was', 'worse', 'than', 'we', 'thoug', '…']
# ['we', 'can', '’', 't', 'let', 'the', 'fake', 'news', ',', 'and', 'their', 'partner', ',', 'the', 'radical', 'left', ',', 'do', 'nothing', 'democrats', ',', 'get', 'away', 'with', 'stealing', 'the', 'election', '.', 'they', 'tried', 'that', 'in', '2016', '.', 'how', 'did', 'that', 'work', 'out', '?']
# ['just', 'announced', ':', 'over', '$', '33', 'million', 'in', 'funding', 'from', 'the', 'hhs', 'has', 'been', 'released', 'to', '#ny21', 'hospitals', '.', 'i', 'will', 'continue', 'to', 'work', 'to', '…']
# ['speaker', 'pelosi', 'still', 'refuses', 'to', 'consider', 'any', 'plan', 'to', 'allow', 'the', 'house', 'to', 'operate', 'or', 'function', 'remotely', '.', 'sidelining', 'and', 'para', '…']
# ['safeguarding', 'our', 'nation', '’', 's', 'food', 'supply', 'is', 'a', 'critical', 'component', 'necessary', 'to', 'defeat', 'the', 'spread', 'of', 'coronavirus', '.', 'i', 'support', 'th', '…']
# ['the', 'flynn', 'documents', 'are', 'out', '.', 'one', 'line', 'is', 'as', 'significant', 'as', 'it', 'is', 'shocking', '.', 'indeed', ',', 'for', 'those', 'who', 'have', 'long', 'seen', 'a', 'conce', '…']
# ['what', 'did', 'fbi', 'director', 'christopher', 'wray', 'know', 'and', 'when', '?', 'and', 'why', 'has', 'he', 'been', 'covering', 'for', 'these', 'scum', 'bags', '?', '…']
# ['#flynn', 'docs', 'just', 'unsealed', ',', 'including', 'handwritten', 'notes', '1/24', '/', '2017', 'day', 'of', 'flynn', 'fbi', 'interview', '.', 'transcript', ':', '“', 'what', 'is', 'our', 'go', '…']
# ['.', 'and', 'i', 'disagree', 'on', 'quite', 'a', 'bit', 'and', 'there', 'are', 'parts', 'of', 'his', 'management', 'of', 'which', 'i', '’', 've', 'been', 'critical', 'but', 'i', '’', 'm', 'glad', '…']
# ['devastating', 'flashback', 'clip', 'of', 'comey', 'just', 'aired', 'on', 'show', '.', 'when', 'asked', 'who', 'went', 'around', 'the', 'protocol', 'of', 'goi', '…']
# ['if', 'you', 'care', 'about', 'liberty', ',', 'freedom', ',', 'or', 'corruption', 'at', 'the', 'highest', 'levels', 'of', 'the', 'government', ',', 'you', 'have', 'to', 'care', 'about', 'gen', '.', '…']
# ['acquitted', 'for', 'life', '.']
# ['proud', '2hear', 'abt', 'collaborative', 'efforts', 'in', 'every', 'sector', 'of', "iowa's", 'economy', 'helping', 'each', 'other', 'is', 'the', 'iowa', 'way', 'recent', 'exampl', '…']
# ['pres', 'is', 'right', '2use', 'authority', '2', 'keep', 'open', 'meat', 'processing', 'plants', 'its', 'critical', 'infrastructure', '4', "country's", '…']
# ['i', 'want', 'to', 'compliment', 'all', 'iowans', 'for', 'coming', 'together', 'to', 'beat', 'this', 'virus', '#iowastrong']
# ['the', 'do', 'nothing', 'democrats', '!']
# ['.', 'kevin', 'mccarthy', '(', 'r-bakersfield', ')', 'announced', 'inyokern', 'airport', 'will', 'receive', 'an', '$', '11', 'million', 'airport', 'improvement', 'pro', '…']
# ['we', '’', 're', 'partnering', 'with', '&', 'to', 'help', 'get', 'ppe', 'and', 'essential', 'goods', 'to', 'communities', 'in', 'need', 'as', 'efficiently', 'as', 'poss', '…']
# ['hey', 'joe', ',', 'last', 'year', 'us', 'emissions', 'dropped', 'by', '2.1', '%', 'largely', 'because', 'of', 'republican-led', 'efforts', 'to', 'deregulate', 'natural', 'gas', ',', 'a', 'c', '…']
# ['wow', '.', 'thousands', 'of', 'job', 'openings', '.', 'looking', 'for', 'work', '?', 'check', 'out', 'this', 'link']
# ['general', 'flynn', ',', 'kavanaugh', ',', 'nicholas', 'sandmann', '-', 'liberal', 'journos', 'are', 'willing', 'to', 'set', 'these', 'people', 'up', 'with', 'lies', 'and', 'then', 'pounce', 'o', '…']
# ['cnn', 'is', 'a', 'part', 'of', 'the', 'problem', 'and', 'they', 'should', 'be', 'sued', 'for', 'spreading', 'lies', 'and', 'propaganda', '!']
# ['what', 'happened', 'to', 'general', 'michael', 'flynn', ',', 'a', 'war', 'hero', ',', 'should', 'never', 'be', 'allowed', 'to', 'happen', 'to', 'a', 'citizen', 'of', 'the', 'united', 'state', '…']
# ['despite', 'reports', 'to', 'the', 'contrary', ',', 'sweden', 'is', 'paying', 'heavily', 'for', 'its', 'decision', 'not', 'to', 'lockdown', '.', 'as', 'of', 'today', ',', '2462', 'people', 'h', '…']
# ['lyin', '’', 'brian', 'williams', 'of', 'msdnc', '!']
# ['i', 'must', 'admit', 'that', 'lyin', '’', 'brian', 'williams', 'is', ',', 'while', 'dumber', 'than', 'hell', ',', 'quite', 'a', 'bit', 'smarter', 'than', 'fake', 'news', '“', 'anchorman', '”', '…']
# ['fake', 'news', '!']
# ['great', '!']
# ['.', 'doesn', '’', 't', 'want', 'to', 'speak', 'about', 'their', 'persecution', 'of', 'general', 'michael', 'flynn', '&', 'why', 'they', 'got', 'the', 'story', 'so', 'wrong', '.', 'they', ',', '…']
# ['dirty', 'cop', 'james', 'comey', 'got', 'caught', '!']
# ['democrats', "didn't", 'expect', 'this', '-', 'washington', 'post', 'poll', ':', 'hispanics', 'are', 'the', 'strongest', 'opponents', 'of', 'immigration', '…']
# ['the', 'economy', 'is', 'going', 'to', 'do', 'so', 'well', 'this', 'summer', 'and', 'make', 'trump', 'look', 'so', 'good', 'that', 'democrats', 'will', 'accuse', 'him', 'of', 'hyping', 'covid', '-', '…']
# ['ryan', 'helfenbein', ':', 'reopening', 'the', 'economy', 'is', 'not', 'partisan', ',', 'it', '’', 's', 'necessary']
# ['hey', 'democrats', ',', "aren't", 'you', 'concerned', 'bernie', 'voters', "didn't", 'show', 'up', 'in', 'the', 'primaries', '?']
# ['imagine', 'having', 'your', 'life', 'and', 'reputation', 'ruined', 'by', 'rogue', 'us', 'govt', '.', 'officials', '.', 'then', 'years', 'later', 'when', 'the', 'plot', 'finally', 'come', '…']
# ['the', 'only', 'person', 'on', 'the', 'planet', 'who', 'thinks', 'comey', 'is', 'a', 'decent', 'human', 'being', 'is', 'comey', '.', 'we', 'now', 'know', 'what', 'a', 'corrupt', 'piece', 'of', 'garbage', '…']
# ['#slowwalker', '-', 'breaking', ':', 'former', 'fbi', 'general', 'counsel', 'james', 'baker', 'has', 'flipped', '!', 'durham', 'is', 'building', 'conspiracy', 'case', 'on', 'all', 'of', 't', '…']
# ['flynn', 'attorney', 'sidney', 'powell', ':', 'the', 'documents', 'that', 'are', 'yet', 'to', 'be', 'released', '"', 'are', 'even', 'more', 'stunning', '"', '(', 'video', ')', '…']
# ['general', 'flynn', 'posts', 'triumphant', 'tweet', 'following', 'release', 'of', 'handwritten', 'fbi', 'notes', 'revealing', 'he', 'was', 'framed', '…']
# ['i', 'have', 'yet', 'to', 'read', 'a', 'single', 'democrat', 'leader', 'outraged', 'by', 'the', 'explosive', 'new', 'flynn', 'revelations', '.', "shouldn't", 'they', 'be', '?', 'shouldn', "'", '…']
# ['turns', 'out', 'the', 'only', 'ones', 'who', 'colluded', 'with', 'russians', 'were', 'hillary', 'clinton', '’', 's', 'campaign', '&', 'the', 'dnc', '.', 'time', 'for', 'comey', '’', 's', 'crooked', 'c', '…']
# ['plus', 'many', '!']
# ['thank', 'you', 'to', 'all', 'of', 'the', 'conservative', 'media', 'figures', 'who', 'doggedly', 'reported', 'on', 'the', 'grotesque', 'attack', 'on', 'general', 'flynn', 'for', 'years', '.', '…']
# ['not', 'only', 'should', 'general', 'flynn', '’', 's', 'charges', 'be', 'dropped', 'immediately', 'but', 'the', 'treasonous', 'actors', 'who', 'set', 'him', 'up', 'should', 'be', 'in', 'ja', '…']
# ['really', '?', 'have', 'you', 'looked', 'at', 'the', 'numbers', 'lately', '!']
# ['fake', 'polling', ',', 'just', 'like', '2016', '(', 'but', 'worse', ')', '!']
# ['what', 'happened', 'to', 'general', 'michael', 'flynn', ',', 'a', 'war', 'hero', ',', 'should', 'never', 'be', 'allowed', 'to', 'happen', 'to', 'a', 'citizen', 'of', 'the', 'united', 'states', 'again', '!']
# ['joe', 'biden', 'forgot', "he's", 'supposed', 'to', 'be', 'lying', 'about', 'president', "trump's", 'coronavirus', 'response', '–', 'and', 'he', 'actually', 'told', 'the', 'truth', '!', '…']
# ['joe', 'biden', 'spent', '44', 'years', 'in', 'washington', 'standing', 'up', 'for', 'china', '.', 'you', "can't", 'teach', 'an', 'old', 'dog', 'new', 'tricks', '.', '…']
# ['the', 'only', 'reason', 'the', 'u', '.', 's', '.', 'has', 'reported', 'one', 'million', 'cases', 'of', 'coronavirus', 'is', 'that', 'our', 'testing', 'is', 'sooo', 'much', 'better', 'than', 'any', 'other', 'country', 'in', 'the', 'world', '.', 'other', 'countries', 'are', 'way', 'behind', 'us', 'in', 'testing', ',', 'and', 'therefore', 'show', 'far', 'fewer', 'cases', '!']
# ['thank', 'you', 'michael', '!']
# ['we', 'built', 'the', 'greatest', 'economy', 'in', 'the', 'world', '—', 'and', 'together', ',', 'we', 'will', 'build', 'it', 'again', '!']
# ['thank', 'you', ',', 'president', ',', 'for', 'your', 'steadfast', ',', 'unapologetic', 'support', 'of', 'law', 'enforcement', 'during', '#covid19', '.', 'from', 'day', 'one', '…']
# []
# []
# ['live', ':', 'potus', 'delivers', 'remarks', 'on', 'supporting', 'small', 'businesses']
# ['thank', 'you', 'and', '!', '#americastrong']
# ['breaking', ':', 'emails', 'show', 'obama', 'fbi', 'was', 'out', 'to', 'get', 'and', 'also', 'knew', 'mccain', 'leaked', 'anti', '-', 'dossier', ';', '…']
# ['a', 'fifth', 'to', 'half', 'of', 'all', 'coronavirus', 'deaths', 'have', 'been', 'in', 'nursing', 'homes', ':']
# ['newly', 'declassified', 'documents', 'show', 'john', 'kerry', '’', 's', 'state', 'department', 'spread', 'russia', 'collusion', 'narrative']
# ['newly', 'revealed', 'docs', 'support', 'flynn', '’', 's', 'innocence', ':', 'case', 'against', 'him', 'should', 'be', 'tossed']
# ['but', 'i', 'love', 'diamond', '&', 'silk', ',', 'and', 'so', 'do', 'millions', 'of', 'people', '!']
# ['45', 'days', 'ago', ',', 'business', 'leaders', 'joined', 'president', 'in', 'the', 'rose', 'garden', 'to', 'help', 'launch', 'a', 'new', ',', 'critical', 'partnersh', '…']
# ['texas', 'to', 'open', 'businesses', 'in', 'phases', 'beginning', 'friday', '.', 'great', 'job', 'being', 'done', 'by']
# ['many', 'states', 'moving', 'to', 'safely', '&', 'quickly', 'reopen', '!']
# ['we', 'are', 'doing', 'far', 'more', ',', 'and', 'better', ',', 'testing', 'than', 'any', 'other', 'country', 'in', 'the', 'world', ',', 'and', 'yet', 'the', 'media', 'does', 'nothing', 'but', 'complain', '.', 'no', 'matter', 'how', 'good', 'a', 'job', 'is', 'done', ',', 'the', 'same', 'as', 'with', 'the', 'ventilators', ',', 'they', 'will', 'never', 'say', 'we', 'are', 'doing', 'a', 'great', 'job', ',', 'they', 'will', 'only', 'viciously', 'gripe', '!']
# ['first', ',', 'there', 'is', 'no', 'shortage', 'of', 'meat', 'destined', 'for', 'the', 'grocery', 'store', 'shelf', '.', 'it', 'might', 'take', 'stores', 'longer', 'than', 'usual', 'to', 'resto', '…']
# []
# ['attorney', 'general', 'barr', '’', 's', 'memo', 'to', 'u', '.', 's', '.', 'attorneys', ':', '“', 'the', 'constitution', 'is', 'not', 'suspended', 'in', 'times', 'of', 'crisis', '.', '”', 'the', 'attorney', 'ge', '…']
# ['because', 'shifty', 'is', 'a', 'crooked', 'politician', '!']
# ['fake', 'news', ',', 'the', 'enemy', 'of', 'the', 'people', '!']
# ['there', 'has', 'never', 'been', ',', 'in', 'the', 'history', 'of', 'our', 'country', ',', 'a', 'more', 'vicious', 'or', 'hostile', 'lamestream', 'media', 'than', 'there', 'is', 'right', 'no', '…']
# ['blame', 'the', 'democrats', 'for', 'any', '“', 'lateness', '”', 'in', 'your', 'enhanced', 'unemployment', 'insurance', '.', 'i', 'wanted', 'the', 'money', 'to', 'be', 'paid', 'directly', '…']
# ['so', 'true', '!']
# ['president', "'", 's', 'plan', 'for', 'opening', 'up', 'america', 'again', 'outlined', 'a', 'three-phased', 'approach', 'based', 'on', 'the', 'advice', 'of', 'publ', '…']
# []
# ['"', "we're", 'doing', 'everything', 'in', 'our', 'power', 'to', 'heal', 'the', 'sick', 'and', 'to', 'gradually', 'reopen', 'our', 'nation', '.', '"']
# ['as', 'one', 'american', 'family', ',', 'we', 'grieve', 'with', 'those', 'who', 'have', 'suffered', 'the', 'loss', 'of', 'loved', 'ones', '.']
# ['live', ':', 'president', 'holds', 'a', 'news', 'conference']
# ['i', 'will', 'be', 'having', 'a', 'white', 'house', 'press', 'conference', 'today', 'at', '5:30', 'p', '.', 'm', '.', 'thank', 'you', '!']
# ['why', 'should', 'the', 'people', 'and', 'taxpayers', 'of', 'america', 'be', 'bailing', 'out', 'poorly', 'run', 'states', '(', 'like', 'illinois', ',', 'as', 'example', ')', 'and', 'cities', ',', 'in', 'all', 'cases', 'democrat', 'run', 'and', 'managed', ',', 'when', 'most', 'of', 'the', 'other', 'states', 'are', 'not', 'looking', 'for', 'bailout', 'help', '?', 'i', 'am', 'open', 'to', 'discussing', 'anything', ',', 'but', 'just', 'asking', '?']
# ['fake', 'news', ',', 'the', 'enemy', 'of', 'the', 'people', '!']
# ['there', 'has', 'never', 'been', ',', 'in', 'the', 'history', 'of', 'our', 'country', ',', 'a', 'more', 'vicious', 'or', 'hostile', 'lamestream', 'media', 'than', 'there', 'is', 'right', 'now', ',', 'even', 'in', 'the', 'midst', 'of', 'a', 'national', 'emergency', ',', 'the', 'invisible', 'enemy', '!']
# ['blame', 'the', 'democrats', 'for', 'any', '“', 'lateness', '”', 'in', 'your', 'enhanced', 'unemployment', 'insurance', '.', 'i', 'wanted', 'the', 'money', 'to', 'be', 'paid', 'directly', ',', 'they', 'insisted', 'it', 'be', 'paid', 'by', 'states', 'for', 'distribution', '.', 'i', 'told', 'them', 'this', 'would', 'happen', ',', 'especially', 'with', 'many', 'states', 'which', 'have', 'old', 'computers', '.']
# ['so', 'true', '!']
# ['i', 'never', 'said', 'the', 'pandemic', 'was', 'a', 'hoax', '!', 'who', 'would', 'say', 'such', 'a', 'thing', '?', 'i', 'said', 'that', 'the', 'do', 'nothing', 'democrats', ',', 'together', 'with', '…']
# ['the', 'people', 'that', 'know', 'me', 'and', 'know', 'the', 'history', 'of', 'our', 'country', 'say', 'that', 'i', 'am', 'the', 'hardest', 'working', 'president', 'in', 'history', '.', 'i', '…']
# ['sloppy', 'joe', 'is', 'trending', '.', 'i', 'wonder', 'if', "it's", 'because', 'of', 'this', '.', 'you', 'can', 'tell', "it's", 'a', 'deep', 'fake', 'because', 'jill', 'biden', "isn't", 'covering', 'f', '…']
# ['article', 'should', 'have', 'read', ':', 'trump', 'as', 'businessman', 'had', 'a', 'passive', ',', 'non-controlling', '/', 'managing', 'interest', 'in', 'an', 'office', 'building', 'which', '…']
# ['devin', 'nunes', '-', '“', 'why', 'is', 'general', 'flynn', 'important', '?', 'because', 'he', 'was', 'framed', 'by', 'his', 'own', 'government', '!', '!', '”', '#humanscum', '…']
# ['despite', 'democrats', 'resistance', 'to', 'help', 'small', 'businesses', ',', 'president', 'will', 'get', 'the', 'economy', 'going', 'and', 'americ', '…']
# ['lefty', 'holier', 'than', 'thou', 'media', 'matters', 'founder', 'david', 'brock', ',', 'who', 'spends', 'millions', 'targeting', 'president', 'trump', ',', 'is', 'accused', 'of', '…']
# ['democrats', 'are', 'not', 'sending', 'us', 'their', 'best', 'or', 'are', 'they', '😜']
# ['here', '’', 's', 'what', 'serial', 'fraudster', ',', '&', 'generational', 'corruptocrat', ',', 'nancy', 'pelosi', 'was', 'really', 'up', 'to', 'when', 'the', 'wuhan', 'virus', 'was', 'raging', '&', 'th', '…']
# ['report', ':', 'fbi', 'knew', 'mccain', 'leaked', 'steele', 'dossier', ',', 'now', 'blames', 'coronavirus', 'for', 'not', 'releasing', 'documents']
# ['former', 'nsc', 'chief', 'of', 'staff', 'says', 'john', 'brennan', 'hid', 'evidence', 'putin', 'favored', 'hillary', 'in', '2016', '🔥', '🔥', '🔥']
# ['you', '’', 're', 'a', 'racist', ',', 'radical', 'communist', 'that', 'wants', 'to', 'expand', 'government', 'control', 'and', 'dependency', '—', 'and', 'you', 'are', 'using', 'the', 'plight', 'o', '…']
# ['once', 'again', ',', 'nancy', 'pelosi', 'is', 'lying', 'about', 'her', 'needless', 'delay', '.', 'she', 'stood', 'in', 'front', 'of', 'her', 'fancy', 'refrigerator', 'and', 'congratula', '…']
# ['wishing', 'you', 'a', 'very', 'special', 'birthday', ',', '.', 'happy', 'birthday', '!', '\U0001f973', '🎂']
# ['american', 'citizens', '!', 'we', 'were', 'long', 'ahead', 'of', 'dems', ',', 'who', 'were', 'all', 'against', 'the', 'ban', '.']
# ['three', 'failed', 'coup', 'attempts', ':', '1', '-', 'russia', 'collusion', 'hoax', 'during', 'campaign', '2', '-', "mueller's", 'sham', '3', '-', 'illegitimate', 'impeachment', '…']
# ['breaking', 'news', ':', 'sources', 'tell', 'me', 'will', 'be', 'completely', 'exonerated', 'this', 'week', '.', 'it', 'was', 'a', 'total', 'fraud', '.', 'a', 'set', 'up', '.', 'mo', '…']
# ['great', '!']
# ['dear', 'god', ',', 'thank', 'you', 'for', 'answering', 'our', 'prayers', '.', 'a', 'grateful', 'nation', '#godblessamerica', '🇺', '🇸', '#presidenttrump', '#electionday', '…']
# ['watch', ':', 'team', 'trump', 'online', 'with', ',', 'rep', '.', ',', 'and', 'rep', '.', '!', '#teamtrump', 'text', 'trump', 'to', '88022', 'http', '…']
# ['remember', ',', 'the', 'cure', 'can', '’', 't', 'be', 'worse', 'than', 'the', 'problem', 'itself', '.', 'be', 'careful', ',', 'be', 'safe', ',', 'use', 'common', 'sense', '!']
# ['from', 'day', '1', ',', 'gretchen', 'whitmer', 'has', 'been', 'too', 'focused', 'on', 'politics', '.', 'case', 'in', 'point', ':', 'she', 'just', 'claimed', 'she', 'is', '“', 'not', 'getting', 'invo', '…']
# ['they', 'are', 'one', 'of', 'the', 'worst', 'in', 'the', '“', 'news', '”', 'business', '.', 'total', 'slime', 'balls', '!']
# ['they', 'asked', 'me', 'to', 'be', 'at', 'west', 'point', 'on', 'june', '13th', '.', ',', '&', 'i', 'will', 'be', 'there', '!']
# ['"', 'all', 'of', 'american', 'society', 'is', 'engaged', 'and', 'mobilized', 'in', 'the', 'war', 'against', 'the', 'invisible', 'enemy', '.', 'while', 'we', 'must', 'remain', 'vigilant', ',', 'it', '…']
# ['we', '’', 're', 'seeing', 'enthusiasm', 'like', 'this', 'all', 'across', 'the', 'country', '.', 'thank', 'you', 'to', 'all', 'the', 'supporters', 'who', 'pitched', 'i', '…']

# %%
import string
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
stopwords_english = stopwords.words('english')
stemmer = PorterStemmer()
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])
emoticons = emoticons_happy.union(emoticons_sad)

# %%
def cl_tweets(tweet):
    tweet = re.sub(r'\$\w*', '', tweet)
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    tweet = re.sub(r'#', '', tweet)
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
 
    tweets_clean = []    
    for word in tweet_tokens:
        if (word not in stopwords_english and
              word not in emoticons and
                word not in string.punctuation):
            stem_word = stemmer.stem(word)
            tweets_clean.append(stem_word)
 
    return tweets_clean

# %%
cl_tw = []
for tweet in clean_tw:
    cl_tw.append(cl_tweets(tweet))

# %%
cl_tw
# Out:
# [['thank', 'michael', 'also'],
#  ['fbi',
#   'found',
#   'derogatori',
#   'inform',
#   'decid',
#   'crush',
#   'anyway',
#   'noth',
#   'wors',
#   '…'],
#  ['russia',
#   'hoax',
#   'biggest',
#   'polit',
#   'scandal',
#   'american',
#   'histori',
#   'treason',
#   'let',
#   'see',
#   'end'],
#  ['join',
#   'quick',
#   'laugh',
#   'funniest',
#   'trump',
#   'kill',
#   'shot',
#   'biden',
#   'ever',
#   '🤣',
#   '🤣',
#   '🤣'],
#  ['kill',
#   'shot',
#   'perfectli',
#   'execut',
#   'pain',
#   'watch',
#   '. . .',
#   'still',
#   'funni',
#   '🤣',
#   '🤣',
#   '🤣'],
#  ['poll',
#   'democrat',
#   'awar',
#   'polit',
#   'news',
#   'consum',
#   'either',
#   'mislead',
#   'cont',
#   '…'],
#  ['greg',
#   'gutfeld',
#   'biden',
#   'respons',
#   'tara',
#   'read',
#   'claim',
#   'great',
#   'interview',
#   'confess',
#   '…'],
#  ['absolut', 'disgrac', "they'v", 'done', 'famili', 'one', 'highli', '…'],
#  ['msm', 'ignor', 'peopl', 'ignor', 'care', 'american', 'worker', '…'],
#  ['sleepi', 'joe', 'fell', 'asleep', 'last', 'town', 'hall'],
#  ['thank'],
#  ['rate', 'support', 'trump', 'republican', 'gone', 'entir', 'mad'],
#  ['democrat',
#   'stick',
#   'togeth',
#   "that'",
#   'lesson',
#   'republican',
#   'parti',
#   'need',
#   'learn',
#   'support',
#   '…'],
#  ['far',
#   'concern',
#   '100',
#   'approv',
#   'republican',
#   'parti',
#   'what',
#   'wrong',
#   'wi',
#   '…'],
#  ['96',
#   'approv',
#   'rate',
#   'republican',
#   'parti',
#   'thank',
#   'also',
#   'highest',
#   'ever',
#   'approv',
#   'rate',
#   'overal',
#   'new',
#   'gallup',
#   'poll',
#   'show',
#   '“',
#   'trump',
#   'beat',
#   'sleepi',
#   'joe',
#   'biden',
#   '”'],
#  ['tremend',
#   'coronaviru',
#   'test',
#   'capac',
#   'washington',
#   'senat',
#   'return',
#   'capit',
#   'hill',
#   'monday',
#   'likewis',
#   'hous',
#   'return',
#   '’',
#   'crazi',
#   'nanci',
#   'p',
#   '5',
#   'minut',
#   'abbott',
#   'test',
#   'use',
#   'pleas',
#   'inform',
#   'dr',
#   'brian',
#   'p',
#   'monahan'],
#  [],
#  ['stun',
#   'silenc',
#   'say',
#   'come',
#   'sexual',
#   'assault',
#   'alleg',
#   'joe',
#   'biden',
#   '’',
#   '“',
#   '”',
#   'mo',
#   '…'],
#  ['fbi',
#   'knew',
#   'michael',
#   'flynn',
#   '’',
#   'collud',
#   'russia',
#   'plot',
#   '‘',
#   'get',
#   'lie',
#   '’',
#   'new',
#   'document',
#   'reveal',
#   '…'],
#  ['’', 'allow', 'rig', 'elect'],
#  ['thank',
#   'dr',
#   'lockwood',
#   'medic',
#   'staff',
#   'contribut',
#   'perspect',
#   'florida',
#   '‘',
#   'fight',
#   '…'],
#  ['posit',
#   'rate',
#   'covid',
#   '19',
#   'test',
#   'nation',
#   'start',
#   'declin',
#   'test',
#   'expand',
#   'sharpli',
#   'move',
#   'te',
#   '…'],
#  ['must',
#   'travel',
#   'take',
#   'step',
#   'protect',
#   'other',
#   'covid',
#   '19',
#   'trip',
#   'http',
#   '…'],
#  ['big',
#   'win',
#   'patient',
#   'first',
#   'build',
#   'block',
#   'improv',
#   'toolbox',
#   'reduc',
#   'death',
#   'disea',
#   '…'],
#  [],
#  [],
#  ['presid',
#   'honor',
#   'sever',
#   'individu',
#   'today',
#   'respond',
#   'invis',
#   'enemi',
#   'courag',
#   'deter',
#   '…'],
#  ['fdni',
#   'member',
#   'show',
#   'appreci',
#   '100',
#   'nation',
#   'ambul',
#   'contract',
#   'unit',
#   'deploy',
#   'back',
#   'home',
#   '30',
#   'day',
#   'spent',
#   '…'],
#  ["tomorrow'",
#   'americastrong',
#   'flyover',
#   'serv',
#   'salut',
#   'frontlin',
#   'covid',
#   'respond',
#   'inthistogeth',
#   '🇺',
#   '🇸',
#   '…'],
#  ['live', 'presid', 'presidenti', 'recognit', 'ceremoni'],
#  [],
#  ['...',
#   'togeth',
#   'fight',
#   'small',
#   'busi',
#   'protect',
#   'american',
#   'energi',
#   'worker',
#   'shelley',
#   'complet',
#   'total',
#   'endors'],
#  ['senat',
#   'shelley',
#   'moor',
#   'capito',
#   'tremend',
#   'job',
#   'great',
#   'peopl',
#   'west',
#   'virginia',
#   'strongli',
#   'defend',
#   'second',
#   'amend',
#   'support',
#   'veteran',
#   'strong',
#   'life',
#   'border',
#   '...'],
#  ['concast',
#   'fake',
#   'news',
#   'go',
#   'way',
#   'say',
#   'great',
#   'thing',
#   'china',
#   'chines',
#   'puppet',
#   'want',
#   'busi',
#   'use',
#   'usa',
#   'airwav',
#   'help',
#   'china',
#   'enemi',
#   'peopl'],
#  ['trump',
#   'get',
#   'bump',
#   'latest',
#   'gallup',
#   'poll',
#   '49',
#   'approv',
#   '6',
#   'tie',
#   'best',
#   '47',
#   'disapprov',
#   '7'],
#  ['governor',
#   'michigan',
#   'give',
#   'littl',
#   'put',
#   'fire',
#   'good',
#   'peopl',
#   'angri',
#   'want',
#   'live',
#   'back',
#   'safe',
#   'see',
#   'talk',
#   'make',
#   'deal'],
#  ['cryin',
#   'chuck',
#   'schumer',
#   'compar',
#   'senat',
#   'brought',
#   'home',
#   'state',
#   'brought',
#   'littl',
#   'back',
#   'n',
#   'total',
#   'overr',
#   'loser',
#   'one',
#   'thing',
#   'given',
#   'salt',
#   'never',
#   'even',
#   'call',
#   'stop',
#   'wonder',
#   'cuomo',
#   'other',
#   '’',
#   'stand',
#   'aoc'],
#  ['cryin',
#   '’',
#   'chuck',
#   'schumer',
#   'late',
#   'night',
#   'show',
#   'use',
#   'fals',
#   'talk',
#   'point',
#   '“',
#   '’',
#   'enough',
#   'test',
#   '”',
#   'would',
#   'repeat',
#   'know',
#   'done',
#   'great',
#   'job',
#   'test',
#   'like',
#   'ventil',
#   'everyth',
#   'els',
#   'lie',
#   'gave',
#   'ny',
#   'salt',
#   'run',
#   'aoc'],
#  ['presid',
#   '“',
#   '’',
#   'spent',
#   '8',
#   'trillion',
#   'dollar',
#   'middl',
#   'east',
#   '’',
#   'fix',
#   'road',
#   '”',
#   '…'],
#  ['presid',
#   '’',
#   'leadership',
#   'gave',
#   'author',
#   'defens',
#   'product',
#   'act',
#   '…'],
#  ['dirti', 'cop'],
#  ['sinc',
#   'first',
#   'day',
#   'pandem',
#   'presid',
#   'brought',
#   'whole',
#   'america',
#   'respons',
#   '’',
#   'make',
#   'gr',
#   '…'],
#  ['done', 'farmer', 'rancher', 'presid', 'histori', 'honor'],
#  ['presid',
#   'use',
#   'defens',
#   'product',
#   'act',
#   'ensur',
#   'american',
#   'reliabl',
#   'suppli',
#   'beef',
#   'por',
#   '…'],
#  ['support',
#   'work',
#   'hard',
#   'everi',
#   'day',
#   'get',
#   'messag',
#   '’',
#   'leadership',
#   '’',
#   'go',
#   '…'],
#  ['alway',
#   'care',
#   '\u2066',
#   '\u2069',
#   'even',
#   'cautiou',
#   '\u2066',
#   '\u2069',
#   'point',
#   'direct',
#   '…'],
#  ['ccp',
#   '’',
#   'military-civil',
#   'fusion',
#   'strategi',
#   'blur',
#   'distinct',
#   'chines',
#   'militari',
#   'civilian',
#   'end-us',
#   'commend',
#   '…'],
#  ['tremend',
#   'work',
#   'rest',
#   'media',
#   'credul',
#   'lazi',
#   'case',
#   'dug',
#   'real',
#   'rep',
#   '…'],
#  ['someth', 'seem', 'rotten', "flynn'", 'case', '—', 'column', '...'],
#  ['ultim', 'respons', '’', 'dirti', 'investig'],
#  ['“',
#   'thing',
#   'got',
#   'wrong',
#   'even',
#   'wors',
#   'corrupt',
#   'thought',
#   '”',
#   'dirti',
#   'cop'],
#  ['new',
#   'doj',
#   'flynn',
#   'doc',
#   'stamp',
#   'w',
#   'sco',
#   'special',
#   'counsel',
#   'offic',
#   'mueller',
#   'doc',
#   'team',
#   'sit',
#   '…'],
#  ['vote',
#   'may',
#   '12th',
#   'oppon',
#   'vote',
#   'fire',
#   'teacher',
#   'cut',
#   'salari',
#   'bump',
#   'pay',
#   '’',
#   'mock',
#   'great',
#   'vet',
#   'need',
#   'navi',
#   'fighter',
#   'pilot',
#   'mike',
#   'garcia',
#   'ca25'],
#  ['...',
#   'strong',
#   'crime',
#   'border',
#   'second',
#   'amend',
#   'tom',
#   'deep',
#   'root',
#   'wisconsin',
#   'big',
#   'tax',
#   'cutter',
#   'help',
#   'drain',
#   'swamp',
#   'tom',
#   'complet',
#   'total',
#   'endors',
#   'vote',
#   'tom',
#   'tiffani'],
#  ['tom',
#   'tiffani',
#   'great',
#   'advoc',
#   'incred',
#   'peopl',
#   'wisconsin',
#   'wi07',
#   'need',
#   'tom',
#   'congress',
#   'help',
#   'us',
#   'make',
#   'america',
#   'great',
#   'fight',
#   'small',
#   'busi',
#   'support',
#   'incred',
#   'farmer',
#   'love',
#   'militari',
#   'vet',
#   '...'],
#  ['live', 'potu', 'deliv', 'remark', 'protect', "america'", 'senior'],
#  ['120',
#   'million',
#   'econom',
#   'impact',
#   'payment',
#   'alreadi',
#   'gone',
#   'hardwork',
#   'american',
#   '’',
#   'yet',
#   'receiv',
#   'payment',
#   'go',
#   'click',
#   '“',
#   'get',
#   'payment',
#   '”',
#   'receiv',
#   'money',
#   'fast'],
#  ['presid',
#   'met',
#   'coronaviru',
#   'test',
#   'financi',
#   'assist',
#   'plan',
#   'great',
#   'come',
#   '…'],
#  ['presid', "we'r", 'work', 'hard', 'new', 'jersey'],
#  ['alreadi',
#   'knew',
#   'jame',
#   "comey'",
#   'fbi',
#   'get',
#   'gener',
#   'flynn',
#   'presid',
#   'trump',
#   'wors',
#   'thoug',
#   '…'],
#  ['’',
#   'let',
#   'fake',
#   'news',
#   'partner',
#   'radic',
#   'left',
#   'noth',
#   'democrat',
#   'get',
#   'away',
#   'steal',
#   'elect',
#   'tri',
#   '2016',
#   'work'],
#  ['announc',
#   'million',
#   'fund',
#   'hh',
#   'releas',
#   'ny21',
#   'hospit',
#   'continu',
#   'work',
#   '…'],
#  ['speaker',
#   'pelosi',
#   'still',
#   'refus',
#   'consid',
#   'plan',
#   'allow',
#   'hous',
#   'oper',
#   'function',
#   'remot',
#   'sidelin',
#   'para',
#   '…'],
#  ['safeguard',
#   'nation',
#   '’',
#   'food',
#   'suppli',
#   'critic',
#   'compon',
#   'necessari',
#   'defeat',
#   'spread',
#   'coronaviru',
#   'support',
#   'th',
#   '…'],
#  ['flynn',
#   'document',
#   'one',
#   'line',
#   'signific',
#   'shock',
#   'inde',
#   'long',
#   'seen',
#   'conc',
#   '…'],
#  ['fbi', 'director', 'christoph', 'wray', 'know', 'cover', 'scum', 'bag', '…'],
#  ['flynn',
#   'doc',
#   'unseal',
#   'includ',
#   'handwritten',
#   'note',
#   '1/24',
#   '2017',
#   'day',
#   'flynn',
#   'fbi',
#   'interview',
#   'transcript',
#   '“',
#   'go',
#   '…'],
#  ['disagre', 'quit', 'bit', 'part', 'manag', '’', 'critic', '’', 'glad', '…'],
#  ['devast',
#   'flashback',
#   'clip',
#   'comey',
#   'air',
#   'show',
#   'ask',
#   'went',
#   'around',
#   'protocol',
#   'goi',
#   '…'],
#  ['care',
#   'liberti',
#   'freedom',
#   'corrupt',
#   'highest',
#   'level',
#   'govern',
#   'care',
#   'gen',
#   '…'],
#  ['acquit', 'life'],
#  ['proud',
#   '2hear',
#   'abt',
#   'collabor',
#   'effort',
#   'everi',
#   'sector',
#   "iowa'",
#   'economi',
#   'help',
#   'iowa',
#   'way',
#   'recent',
#   'exampl',
#   '…'],
#  ['pre',
#   'right',
#   '2use',
#   'author',
#   '2',
#   'keep',
#   'open',
#   'meat',
#   'process',
#   'plant',
#   'critic',
#   'infrastructur',
#   '4',
#   "country'",
#   '…'],
#  ['want',
#   'compliment',
#   'iowan',
#   'come',
#   'togeth',
#   'beat',
#   'viru',
#   'iowastrong'],
#  ['noth', 'democrat'],
#  ['kevin',
#   'mccarthi',
#   'r-bakersfield',
#   'announc',
#   'inyokern',
#   'airport',
#   'receiv',
#   'million',
#   'airport',
#   'improv',
#   'pro',
#   '…'],
#  ['’',
#   'partner',
#   'help',
#   'get',
#   'ppe',
#   'essenti',
#   'good',
#   'commun',
#   'need',
#   'effici',
#   'poss',
#   '…'],
#  ['hey',
#   'joe',
#   'last',
#   'year',
#   'us',
#   'emiss',
#   'drop',
#   '2.1',
#   'larg',
#   'republican-l',
#   'effort',
#   'deregul',
#   'natur',
#   'ga',
#   'c',
#   '…'],
#  ['wow', 'thousand', 'job', 'open', 'look', 'work', 'check', 'link'],
#  ['gener',
#   'flynn',
#   'kavanaugh',
#   'nichola',
#   'sandmann',
#   'liber',
#   'journo',
#   'will',
#   'set',
#   'peopl',
#   'lie',
#   'pounc',
#   '…'],
#  ['cnn', 'part', 'problem', 'su', 'spread', 'lie', 'propaganda'],
#  ['happen',
#   'gener',
#   'michael',
#   'flynn',
#   'war',
#   'hero',
#   'never',
#   'allow',
#   'happen',
#   'citizen',
#   'unit',
#   'state',
#   '…'],
#  ['despit',
#   'report',
#   'contrari',
#   'sweden',
#   'pay',
#   'heavili',
#   'decis',
#   'lockdown',
#   'today',
#   '2462',
#   'peopl',
#   'h',
#   '…'],
#  ['lyin', '’', 'brian', 'william', 'msdnc'],
#  ['must',
#   'admit',
#   'lyin',
#   '’',
#   'brian',
#   'william',
#   'dumber',
#   'hell',
#   'quit',
#   'bit',
#   'smarter',
#   'fake',
#   'news',
#   '“',
#   'anchorman',
#   '”',
#   '…'],
#  ['fake', 'news'],
#  ['great'],
#  ['’',
#   'want',
#   'speak',
#   'persecut',
#   'gener',
#   'michael',
#   'flynn',
#   'got',
#   'stori',
#   'wrong',
#   '…'],
#  ['dirti', 'cop', 'jame', 'comey', 'got', 'caught'],
#  ['democrat',
#   'expect',
#   'washington',
#   'post',
#   'poll',
#   'hispan',
#   'strongest',
#   'oppon',
#   'immigr',
#   '…'],
#  ['economi',
#   'go',
#   'well',
#   'summer',
#   'make',
#   'trump',
#   'look',
#   'good',
#   'democrat',
#   'accus',
#   'hype',
#   'covid',
#   '…'],
#  ['ryan', 'helfenbein', 'reopen', 'economi', 'partisan', '’', 'necessari'],
#  ['hey', 'democrat', 'concern', 'berni', 'voter', 'show', 'primari'],
#  ['imagin',
#   'life',
#   'reput',
#   'ruin',
#   'rogu',
#   'us',
#   'govt',
#   'offici',
#   'year',
#   'later',
#   'plot',
#   'final',
#   'come',
#   '…'],
#  ['person',
#   'planet',
#   'think',
#   'comey',
#   'decent',
#   'human',
#   'comey',
#   'know',
#   'corrupt',
#   'piec',
#   'garbag',
#   '…'],
#  ['slowwalk',
#   'break',
#   'former',
#   'fbi',
#   'gener',
#   'counsel',
#   'jame',
#   'baker',
#   'flip',
#   'durham',
#   'build',
#   'conspiraci',
#   'case',
#   '…'],
#  ['flynn',
#   'attorney',
#   'sidney',
#   'powel',
#   'document',
#   'yet',
#   'releas',
#   'even',
#   'stun',
#   'video',
#   '…'],
#  ['gener',
#   'flynn',
#   'post',
#   'triumphant',
#   'tweet',
#   'follow',
#   'releas',
#   'handwritten',
#   'fbi',
#   'note',
#   'reveal',
#   'frame',
#   '…'],
#  ['yet',
#   'read',
#   'singl',
#   'democrat',
#   'leader',
#   'outrag',
#   'explos',
#   'new',
#   'flynn',
#   'revel',
#   '…'],
#  ['turn',
#   'one',
#   'collud',
#   'russian',
#   'hillari',
#   'clinton',
#   '’',
#   'campaign',
#   'dnc',
#   'time',
#   'comey',
#   '’',
#   'crook',
#   'c',
#   '…'],
#  ['plu', 'mani'],
#  ['thank',
#   'conserv',
#   'media',
#   'figur',
#   'doggedli',
#   'report',
#   'grotesqu',
#   'attack',
#   'gener',
#   'flynn',
#   'year',
#   '…'],
#  ['gener',
#   'flynn',
#   '’',
#   'charg',
#   'drop',
#   'immedi',
#   'treason',
#   'actor',
#   'set',
#   'ja',
#   '…'],
#  ['realli', 'look', 'number', 'late'],
#  ['fake', 'poll', 'like', '2016', 'wors'],
#  ['happen',
#   'gener',
#   'michael',
#   'flynn',
#   'war',
#   'hero',
#   'never',
#   'allow',
#   'happen',
#   'citizen',
#   'unit',
#   'state'],
#  ['anybodi',
#   'realli',
#   'believ',
#   'roger',
#   'stone',
#   'man',
#   'whose',
#   'hous',
#   'raid',
#   'earli',
#   'morn',
#   '29',
#   'gun',
#   'tote',
#   'fbi',
#   'agent',
#   'fake',
#   'news',
#   'close',
#   'toe',
#   'treat',
#   'fairli',
#   'juri',
#   'forewoman',
#   'unannounc',
#   'hatr',
#   'bia',
#   'scammer',
#   'gener',
#   'flynn'],
#  ['despit',
#   'report',
#   'contrari',
#   'sweden',
#   'pay',
#   'heavili',
#   'decis',
#   'lockdown',
#   'today',
#   '2462',
#   'peopl',
#   'die',
#   'much',
#   'higher',
#   'number',
#   'neighbor',
#   'countri',
#   'norway',
#   '207',
#   'finland',
#   '206',
#   'denmark',
#   '443',
#   'unit',
#   'state',
#   'made',
#   'correct',
#   'decis'],
#  ['lyin', '’', 'brian', 'william', 'msdnc'],
#  ['must',
#   'admit',
#   'lyin',
#   '’',
#   'brian',
#   'william',
#   'dumber',
#   'hell',
#   'quit',
#   'bit',
#   'smarter',
#   'fake',
#   'news',
#   '“',
#   'anchorman',
#   '”',
#   'lemon',
#   '“',
#   'dumbest',
#   'man',
#   'televis',
#   '”',
#   'psycho',
#   'joe',
#   '“',
#   'ever',
#   'happen',
#   'girlfriend',
#   '”',
#   'scarborough',
#   'anoth',
#   'low',
#   'q',
#   'individu'],
#  ['lyin',
#   '’',
#   'brian',
#   'william',
#   'msdnc',
#   'concast',
#   'scam',
#   'compani',
#   '’',
#   'know',
#   'truth',
#   'nail',
#   'wooden',
#   'forehead',
#   'rememb',
#   'lie',
#   'braveri',
#   'helicopt',
#   'total',
#   'made',
#   'stori',
#   '’',
#   'true',
#   'dummi',
#   'thrown',
#   'network',
#   'news',
#   'like',
#   'dog',
#   'stay',
#   'tune'],
#  ['told',
#   'fake',
#   'news',
#   'fals',
#   'report',
#   'recent',
#   'shout',
#   'campaign',
#   'manag',
#   'made',
#   'nonsens',
#   'actual',
#   'great',
#   'job',
#   'never',
#   'shout',
#   'year',
#   'includ',
#   '2016',
#   'win',
#   'intent',
#   'fake',
#   'news'],
#  ['’',
#   'want',
#   'speak',
#   'persecut',
#   'gener',
#   'michael',
#   'flynn',
#   'got',
#   'stori',
#   'wrong',
#   'along',
#   'other',
#   'pay',
#   'big',
#   'price',
#   'purpos',
#   'done',
#   'man',
#   'famili',
#   '’',
#   'even',
#   'cover',
#   'big',
#   'break',
#   'news',
#   'scam'],
#  [],
#  [],
#  ['happi',
#   'birthday',
#   'three',
#   'time',
#   'olympian',
#   'five',
#   'term',
#   'congressman'],
#  [],
#  [],
#  [],
#  ['live', 'potu', 'hold', 'roundtabl', 'industri', 'execut'],
#  ['nation',
#   'ampl',
#   'suppli',
#   'food',
#   '—',
#   'presid',
#   'clear',
#   'bottleneck',
#   'ensur',
#   'farmer',
#   '…'],
#  ['brighter',
#   'day',
#   'ahead',
#   'louisiana',
#   'work',
#   'togeth',
#   'feder',
#   'offici',
#   'know',
#   'get',
#   '…'],
#  ['want', 'thank', 'support', 'peopl', 'louisiana', 'difficult', 'time', '…'],
#  ['grate',
#   'protect',
#   'nation',
#   '’',
#   'food',
#   'suppli',
#   'said',
#   'pre',
#   'ceo',
#   'juli',
#   'ann',
#   '…'],
#  ['think',
#   'amash',
#   'would',
#   'make',
#   'wonder',
#   'candid',
#   'especi',
#   'sinc',
#   'way',
#   'behind',
#   'district',
#   'chanc',
#   'maintain',
#   'congression',
#   'seat',
#   'almost',
#   'alway',
#   'vote',
#   'noth',
#   'dem',
#   'anyway',
#   'like',
#   'even',
#   'jill',
#   'stein'],
#  ['thank'],
#  ['yahoo',
#   'report',
#   'apolog',
#   'presid',
#   'trump',
#   'make',
#   'fals',
#   'coronaviru',
#   'test',
#   'claim',
#   'oval',
#   'offic',
#   'meet',
#   '…'],
#  ['least', 'admit', 'fail', 'never', 'correct', 'fake', 'report'],
#  ['🚨',
#   '🚨',
#   'tune',
#   '🚨',
#   '🚨',
#   'tonight',
#   '’',
#   'onlin',
#   'two',
#   'best',
#   '—',
#   'talk',
#   'slee',
#   '…'],
#  ['watch',
#   'team',
#   'trump',
#   'onlin',
#   'hous',
#   'gop',
#   'leader',
#   'teamtrump',
#   'text',
#   'trump',
#   '88022',
#   '…'],
#  ['tisa',
#   'clark',
#   'ceo',
#   'j',
#   'clark',
#   'profession',
#   'servic',
#   'credit',
#   'paycheckprotectionprogram',
#   'allow',
#   'keep',
#   'wor',
#   '…'],
#  ['trump',
#   'campaign',
#   'senior',
#   'advisor',
#   'said',
#   'today',
#   'joe',
#   "biden'",
#   'plan',
#   'eas',
#   'sanction',
#   'cuban',
#   'venezuel',
#   '…'],
#  ['joe',
#   'biden',
#   'rambl',
#   'struggl',
#   'word',
#   'interview',
#   'coronaviru',
#   'respons'],
#  ['joe',
#   'biden',
#   '’',
#   'town',
#   'hall',
#   'hillari',
#   'clinton',
#   'got',
#   'fantast',
#   'start'],
#  ['report',
#   'angrili',
#   'insist',
#   'right',
#   'coronaviru',
#   'test',
#   'data',
#   'fact',
#   'wrong',
#   'presid',
#   'trump',
#   'r',
#   '…'],
#  ['joe',
#   'biden',
#   'forgot',
#   "he'",
#   'suppos',
#   'lie',
#   'presid',
#   "trump'",
#   'coronaviru',
#   'respons',
#   '–',
#   'actual',
#   'told',
#   'truth',
#   '…'],
#  ['joe',
#   'biden',
#   'spent',
#   '44',
#   'year',
#   'washington',
#   'stand',
#   'china',
#   "can't",
#   'teach',
#   'old',
#   'dog',
#   'new',
#   'trick',
#   '…'],
#  ['reason',
#   'u',
#   'report',
#   'one',
#   'million',
#   'case',
#   'coronaviru',
#   'test',
#   'sooo',
#   'much',
#   'better',
#   'countri',
#   'world',
#   'countri',
#   'way',
#   'behind',
#   'us',
#   'test',
#   'therefor',
#   'show',
#   'far',
#   'fewer',
#   'case'],
#  ['thank', 'michael'],
#  ['built', 'greatest', 'economi', 'world', '—', 'togeth', 'build'],
#  ['thank',
#   'presid',
#   'steadfast',
#   'unapologet',
#   'support',
#   'law',
#   'enforc',
#   'covid',
#   '19',
#   'day',
#   'one',
#   '…'],
#  [],
#  [],
#  ['live', 'potu', 'deliv', 'remark', 'support', 'small', 'busi'],
#  ['thank', 'americastrong'],
#  ['break',
#   'email',
#   'show',
#   'obama',
#   'fbi',
#   'get',
#   'also',
#   'knew',
#   'mccain',
#   'leak',
#   'anti',
#   'dossier',
#   '…'],
#  ['fifth', 'half', 'coronaviru', 'death', 'nurs', 'home'],
#  ['newli',
#   'declassifi',
#   'document',
#   'show',
#   'john',
#   'kerri',
#   '’',
#   'state',
#   'depart',
#   'spread',
#   'russia',
#   'collus',
#   'narr'],
#  ['newli', 'reveal', 'doc', 'support', 'flynn', '’', 'innoc', 'case', 'toss'],
#  ['love', 'diamond', 'silk', 'million', 'peopl'],
#  ['45',
#   'day',
#   'ago',
#   'busi',
#   'leader',
#   'join',
#   'presid',
#   'rose',
#   'garden',
#   'help',
#   'launch',
#   'new',
#   'critic',
#   'partnersh',
#   '…'],
#  ['texa', 'open', 'busi', 'phase', 'begin', 'friday', 'great', 'job', 'done'],
#  ['mani', 'state', 'move', 'safe', 'quickli', 'reopen'],
#  ['far',
#   'better',
#   'test',
#   'countri',
#   'world',
#   'yet',
#   'media',
#   'noth',
#   'complain',
#   'matter',
#   'good',
#   'job',
#   'done',
#   'ventil',
#   'never',
#   'say',
#   'great',
#   'job',
#   'vicious',
#   'gripe'],
#  ['first',
#   'shortag',
#   'meat',
#   'destin',
#   'groceri',
#   'store',
#   'shelf',
#   'might',
#   'take',
#   'store',
#   'longer',
#   'usual',
#   'resto',
#   '…'],
#  [],
#  ['attorney',
#   'gener',
#   'barr',
#   '’',
#   'memo',
#   'u',
#   'attorney',
#   '“',
#   'constitut',
#   'suspend',
#   'time',
#   'crisi',
#   '”',
#   'attorney',
#   'ge',
#   '…'],
#  ['shifti', 'crook', 'politician'],
#  ['fake', 'news', 'enemi', 'peopl'],
#  ['never',
#   'histori',
#   'countri',
#   'viciou',
#   'hostil',
#   'lamestream',
#   'media',
#   'right',
#   '…'],
#  ['blame',
#   'democrat',
#   '“',
#   'late',
#   '”',
#   'enhanc',
#   'unemploy',
#   'insur',
#   'want',
#   'money',
#   'paid',
#   'directli',
#   '…'],
#  ['true'],
#  ['presid',
#   'plan',
#   'open',
#   'america',
#   'outlin',
#   'three-phas',
#   'approach',
#   'base',
#   'advic',
#   'publ',
#   '…'],
#  [],
#  ["we'r", 'everyth', 'power', 'heal', 'sick', 'gradual', 'reopen', 'nation'],
#  ['one', 'american', 'famili', 'griev', 'suffer', 'loss', 'love', 'one'],
#  ['live', 'presid', 'hold', 'news', 'confer'],
#  ['white', 'hous', 'press', 'confer', 'today', '5:30', 'p', 'thank'],
#  ['peopl',
#   'taxpay',
#   'america',
#   'bail',
#   'poorli',
#   'run',
#   'state',
#   'like',
#   'illinoi',
#   'exampl',
#   'citi',
#   'case',
#   'democrat',
#   'run',
#   'manag',
#   'state',
#   'look',
#   'bailout',
#   'help',
#   'open',
#   'discuss',
#   'anyth',
#   'ask'],
#  ['fake', 'news', 'enemi', 'peopl'],
#  ['never',
#   'histori',
#   'countri',
#   'viciou',
#   'hostil',
#   'lamestream',
#   'media',
#   'right',
#   'even',
#   'midst',
#   'nation',
#   'emerg',
#   'invis',
#   'enemi'],
#  ['blame',
#   'democrat',
#   '“',
#   'late',
#   '”',
#   'enhanc',
#   'unemploy',
#   'insur',
#   'want',
#   'money',
#   'paid',
#   'directli',
#   'insist',
#   'paid',
#   'state',
#   'distribut',
#   'told',
#   'would',
#   'happen',
#   'especi',
#   'mani',
#   'state',
#   'old',
#   'comput'],
#  ['true'],
#  ['never',
#   'said',
#   'pandem',
#   'hoax',
#   'would',
#   'say',
#   'thing',
#   'said',
#   'noth',
#   'democrat',
#   'togeth',
#   '…'],
#  ['peopl',
#   'know',
#   'know',
#   'histori',
#   'countri',
#   'say',
#   'hardest',
#   'work',
#   'presid',
#   'histori',
#   '…'],
#  ['sloppi',
#   'joe',
#   'trend',
#   'wonder',
#   'tell',
#   'deep',
#   'fake',
#   'jill',
#   'biden',
#   'cover',
#   'f',
#   '…'],
#  ['articl',
#   'read',
#   'trump',
#   'businessman',
#   'passiv',
#   'non-control',
#   'manag',
#   'interest',
#   'offic',
#   'build',
#   '…'],
#  ['devin',
#   'nune',
#   '“',
#   'gener',
#   'flynn',
#   'import',
#   'frame',
#   'govern',
#   '”',
#   'humanscum',
#   '…'],
#  ['despit',
#   'democrat',
#   'resist',
#   'help',
#   'small',
#   'busi',
#   'presid',
#   'get',
#   'economi',
#   'go',
#   'amer',
#   '…'],
#  ['lefti',
#   'holier',
#   'thou',
#   'media',
#   'matter',
#   'founder',
#   'david',
#   'brock',
#   'spend',
#   'million',
#   'target',
#   'presid',
#   'trump',
#   'accus',
#   '…'],
#  ['democrat', 'send', 'us', 'best', '😜'],
#  ['’',
#   'serial',
#   'fraudster',
#   'gener',
#   'corruptocrat',
#   'nanci',
#   'pelosi',
#   'realli',
#   'wuhan',
#   'viru',
#   'rage',
#   'th',
#   '…'],
#  ['report',
#   'fbi',
#   'knew',
#   'mccain',
#   'leak',
#   'steel',
#   'dossier',
#   'blame',
#   'coronaviru',
#   'releas',
#   'document'],
#  ['former',
#   'nsc',
#   'chief',
#   'staff',
#   'say',
#   'john',
#   'brennan',
#   'hid',
#   'evid',
#   'putin',
#   'favor',
#   'hillari',
#   '2016',
#   '🔥',
#   '🔥',
#   '🔥'],
#  ['’',
#   'racist',
#   'radic',
#   'communist',
#   'want',
#   'expand',
#   'govern',
#   'control',
#   'depend',
#   '—',
#   'use',
#   'plight',
#   '…'],
#  ['nanci',
#   'pelosi',
#   'lie',
#   'needless',
#   'delay',
#   'stood',
#   'front',
#   'fanci',
#   'refriger',
#   'congratula',
#   '…'],
#  ['wish', 'special', 'birthday', 'happi', 'birthday', '\U0001f973', '🎂'],
#  ['american', 'citizen', 'long', 'ahead', 'dem', 'ban'],
#  ['three',
#   'fail',
#   'coup',
#   'attempt',
#   '1',
#   'russia',
#   'collus',
#   'hoax',
#   'campaign',
#   '2',
#   "mueller'",
#   'sham',
#   '3',
#   'illegitim',
#   'impeach',
#   '…'],
#  ['break',
#   'news',
#   'sourc',
#   'tell',
#   'complet',
#   'exoner',
#   'week',
#   'total',
#   'fraud',
#   'set',
#   'mo',
#   '…'],
#  ['great'],
#  ['dear',
#   'god',
#   'thank',
#   'answer',
#   'prayer',
#   'grate',
#   'nation',
#   'godblessamerica',
#   '🇺',
#   '🇸',
#   'presidenttrump',
#   'electionday',
#   '…'],
#  ['watch',
#   'team',
#   'trump',
#   'onlin',
#   'rep',
#   'rep',
#   'teamtrump',
#   'text',
#   'trump',
#   '88022',
#   'http',
#   '…'],
#  ['rememb',
#   'cure',
#   '’',
#   'wors',
#   'problem',
#   'care',
#   'safe',
#   'use',
#   'common',
#   'sens'],
#  ['day',
#   '1',
#   'gretchen',
#   'whitmer',
#   'focus',
#   'polit',
#   'case',
#   'point',
#   'claim',
#   '“',
#   'get',
#   'invo',
#   '…'],
#  ['one', 'worst', '“', 'news', '”', 'busi', 'total', 'slime', 'ball'],
#  ['ask', 'west', 'point', 'june', '13th'],
#  ['american',
#   'societi',
#   'engag',
#   'mobil',
#   'war',
#   'invis',
#   'enemi',
#   'must',
#   'remain',
#   'vigil',
#   '…'],
#  ['’',
#   'see',
#   'enthusiasm',
#   'like',
#   'across',
#   'countri',
#   'thank',
#   'support',
#   'pitch',
#   '…']]

# %%
#feature extrction
def bag_of_words(tweet):
    words = cl_tweets(tweet)
    words_dictionary = dict([word, True] for word in words)    
    return words_dictionary

# %%
from nltk.corpus import twitter_samples

# %%
pos_tweets = twitter_samples.strings('positive_tweets.json')
print (len(pos_tweets)) # Output: 5000
 
neg_tweets = twitter_samples.strings('negative_tweets.json')
print (len(neg_tweets)) # Output: 5000
 
all_tweets = twitter_samples.strings('tweets.20150430-223406.json')
print (len(all_tweets)) # Output: 20000
# Out:
# 5000
# 5000
# 20000

# %%
pos_tweets_set = []
for tweet in pos_tweets:
    pos_tweets_set.append((bag_of_words(tweet), 'pos'))

# %%
neg_tweets_set = []
for tweet in neg_tweets:
    neg_tweets_set.append((bag_of_words(tweet), 'neg'))

# %%
from random import shuffle 
shuffle(pos_tweets_set)
shuffle(neg_tweets_set)
 
test_set = pos_tweets_set[:1000] + neg_tweets_set[:1000]
train_set = pos_tweets_set[1000:] + neg_tweets_set[1000:]
 
print(len(test_set),  len(train_set))
# Out:
# 2000 8000

# %%
from nltk import classify
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(train_set)
 
accuracy = classify.accuracy(classifier, test_set)
print(accuracy)
# Out:
# 0.743

# %%
print (classifier.show_most_informative_features(10))
# Out:
# Most Informative Features
#                      via = True              pos : neg    =     35.0 : 1.0
#                      sad = True              neg : pos    =     26.7 : 1.0
#                      bam = True              pos : neg    =     21.7 : 1.0
#                     blog = True              pos : neg    =     16.3 : 1.0
#                     glad = True              pos : neg    =     15.4 : 1.0
#                    didnt = True              neg : pos    =     14.3 : 1.0
#                       ff = True              pos : neg    =     14.2 : 1.0
#                   welcom = True              pos : neg    =     13.9 : 1.0
#                      bro = True              pos : neg    =     13.7 : 1.0
#                     lost = True              neg : pos    =     13.0 : 1.0
# None

# %%
clean_tw
# Out:
# array(['Thank you Michael. You also! ',
#        ' The FBI found "no derogatory information" about . But they decided to crush him anyway.\n\n"There is nothing worse…',
#        'The Russia Hoax is the biggest political scandal in American history. Treason!!! Lets see how it ends???? ',
#        ' Join me for a quick laugh about the funniest Trump kill shot on Biden. Ever.🤣🤣🤣🤣🤣🤣 ',
#        ' This kill shot is so perfectly executed it is painful to watch . . . and still funny. 🤣🤣🤣',
#        ' Poll for Democrats only. Are you aware that most of the political news you consume is either misleading and out of cont…',
#        " Greg Gutfeld on Biden response to Tara Reade claims: He 'was doing great in that interview until he confessed' …",
#        "  It's an absolute disgrace what they've done to  and his family.\n\nThis is one of the most highly…",
#        "   Why does MSM ignore this???\n\nWhy do people ignore that he doesn't care about the #American worker…",
#        '  Sleepy Joe fell asleep during his last town hall! ',
#        'Thank you! ',
#        "  At this rate, if you don't support Trump and you're a Republican you've gone entirely mad.",
#        "  All of the Democrats stick together, that's a lesson that the Republican party needs to learn, support…",
#        '  As far as I am concerned, it should be a 100% approval from all of the Republican party, whats wrong wi…',
#        '96% Approval Rating in the Republican Party. Thank you! Also, just out, highest ever Approval Rating overall in the new Gallup Poll, and shows “Trump beating Sleepy Joe Biden.”',
#        'There is tremendous CoronaVirus testing capacity in Washington for the Senators returning to Capital Hill on Monday. Likewise the House, which should return but isn’t because of Crazy Nancy P. The 5 minute Abbott Test will be used. Please inform Dr. Brian P. Monahan. ',
#        '',
#        ' Stunning Silence:  says when it comes to sexual assault allegations against Joe Biden, it’s as if the “Me Too” mo…',
#        ' The FBI knew Michael Flynn wasn’t colluding with Russia, so it plotted to ‘get him to lie.’ New documents reveal that, by…',
#        'Don’t allow RIGGED ELECTIONS! ',
#        ' Thank you Dr. Lockwood and medical staff at  for your contributions and perspective on Florida‘s fight against…',
#        ' Positivity rates for covid19 testing nationally are starting to decline as testing expands sharply and we move more te…',
#        ' If you must travel, take these steps to protect yourself &amp; others from #COVID19 during your trip.  https…',
#        ' A big win for patients and the first building block in what will be an improving toolbox for reducing death and diseas…',
#        '', '',
#        ' President  honored several individuals today who have responded to this invisible enemy with courage, deter…',
#        ' FDNY members show their appreciation for 100  National Ambulance Contract units as they deploy back home after 30 days spent…',
#        " Tomorrow's #AmericaStrong flyover serves as a salute to frontline #COVID responders.\n\n#InThisTogether 🇺🇸 …",
#        ' LIVE: President  at Presidential Recognition Ceremony ', '',
#        '....Together we will Fight for Small Businesses and Protect American Energy workers! Shelley has my Complete and Total Endorsement! ',
#        'Senator Shelley Moore Capito () is doing a tremendous job for the great people of West Virginia! She strongly defends our Second Amendment, Supports our Veterans and is Strong on Life and the Border....',
#        'Concast () and Fake News  are going out of their way to say GREAT things about China. They are Chinese puppets who want to do business there. They use USA airwaves to help China. The Enemy of the People!',
#        ' Trump gets bump in latest Gallup Poll:\n49% approval (+6, tied for his best)\n47% disapproval (-7)',
#        'The Governor of Michigan should give a little, and put out the fire. These are very good people, but they are angry. They want their lives back again, safely! See them, talk to them, make a deal.',
#        'Cryin Chuck Schumer, compared to what other Senators have brought home to their states, has brought very little back to N.Y. A totally overrated loser, the one thing he has given them is SALT. He never even called me to stop it. No wonder Cuomo &amp; most others can’t stand him. AOC!',
#        'Cryin’ Chuck Schumer was on a late night show using a false talking point over &amp; over again. “We don’t have enough testing ,” he would repeat, when he knows we have done a great job on Testing, just like we have on Ventilators and everything else. He lied, gave NY SALT. Run AOC!',
#        ' President : “We’ve spent 8 trillion dollars in the Middle East and we’re not fixing our roads.” …',
#        ' Under President ’s leadership, we gave  and  the authority under the Defense Production Act to i…',
#        'Dirty Cop! ',
#        ' Since the first days of this pandemic, President  has brought a whole of America response &amp; we’re making gr…',
#        'I have done more for farmers and ranchers than any President in history, and it has been my honor in doing so! ',
#        ' President  is using the Defense Production Act to ensure that Americans have a reliable supply of beef, por…',
#        ' Our supporters are working hard every day and getting the message out about ’s leadership. We’re going t…',
#        ' The always careful \u2066\u2069 is even more cautious here, but he and \u2066\u2069 are pointing in the same direction…',
#        ' The CCP’s Military-Civil Fusion strategy blurs the distinction between Chinese military &amp; civilian end-users. I commend t…',
#        ' Tremendous work by  \n\nWhile the rest of the media was credulous and lazy about this case, it dug in with real rep…',
#        " Something seems rotten in Flynn's case — my column  ... ",
#        ' . is Ultimately Responsible for ’s Dirty Investigation into \n\n',
#        '“The only thing we got wrong is that it was even worse (the corruption) than we thought.”   DIRTY COPS!',
#        ' New DOJ/Flynn docs are stamped w SCO as in Special Counsels Office\n \nDid Mueller have these docs? Why did his team sit o…',
#        'Vote  by May 12th! His opponent  voted to fire teachers, and cut their salaries while bumping up her pay. Now she’s mocking our Great Vets! We need Navy Fighter Pilot Mike Garcia in #CA25! ',
#        '....He is Strong on Crime, the Border, and Second Amendment. Tom has deep roots in Wisconsin, is a big Tax Cutter, and will help me DRAIN THE SWAMP! Tom has my Complete and Total Endorsement. Vote for Tom Tiffany! ',
#        'Tom Tiffany () is a Great Advocate for the incredible people of Wisconsin (WI07). We need Tom in Congress to help us Make America Great Again! He will Fight for Small Business, supports our Incredible Farmers, Loves our Military and our Vets....',
#        " LIVE: POTUS Delivers Remarks on Protecting America's Seniors ",
#        'Over 120 MILLION Economic Impact Payments have already gone out to hardworking Americans! If you haven’t yet received your payment, go to  and click on “GET MY PAYMENT” to receive your money FAST!',
#        ' President  just met with  on Coronavirus testing, financial assistance, and planning a great come…',
#        ' President : "We\'re working very hard with New Jersey." ',
#        " We already knew that James Comey's FBI was out to get General Flynn and President Trump. \n\nBut it was worse than we thoug…",
#        'We can’t let the Fake News, and their partner, the Radical Left, Do Nothing Democrats, get away with stealing the Election. They tried that in 2016. How did that work out?',
#        ' Just announced: over $33 million in funding from the HHS has been released to #NY21 hospitals. I will continue to work to…',
#        ' Speaker Pelosi still refuses to consider any plan to allow the House to operate or function remotely. Sidelining and para…',
#        ' Safeguarding our nation’s food supply is a critical component necessary to defeat the spread of coronavirus. I support th…',
#        ' The Flynn documents are out. One line is as significant as it is shocking. Indeed, for those who have long seen a conce…',
#        ' What did FBI Director Christopher Wray know and when? And why has he been covering for these scum bags? …',
#        ' #FLYNN docs just unsealed, including handwritten notes 1/24/2017 day of Flynn FBI interview.  Transcript: “What is our go…',
#        ' . and I disagree on quite a bit and there are parts of his management of which I’ve been critical but I’m glad…',
#        ' Devastating flashback clip of Comey just aired on  show.\n\nWhen asked who went around the protocol of goi…',
#        ' If you care about liberty, freedom, or corruption at the highest levels of the government, you have to care about Gen.…',
#        ' ACQUITTED FOR LIFE. ',
#        " Proud 2hear abt collaborative efforts in every sector of Iowa's economy Helping each other is the Iowa way Recent exampl…",
#        " Pres  is right 2use authority 2 keep open meat processing plants Its critical infrastructure 4 country's…",
#        ' I want to compliment all Iowans for coming together to beat this virus #IowaStrong ',
#        'The Do Nothing Democrats! ',
#        ' . Kevin McCarthy (R-Bakersfield) announced InyoKern Airport will receive an $11 million Airport Improvement Pro…',
#        ' We’re partnering with  &amp;  to help get PPE and essential goods to communities in need as efficiently as poss…',
#        ' Hey Joe, last year US emissions dropped by 2.1% largely because of Republican-led efforts to deregulate natural gas, a c…',
#        ' Wow. Thousands of job openings. \n\nLooking for work? Check out this link ',
#        ' General Flynn, Kavanaugh, Nicholas Sandmann- liberal journos are willing to set these people up with lies and then pounce o…',
#        '   CNN is a part of the problem and they should be sued for spreading lies and propaganda!',
#        ' What happened to General Michael Flynn, a war hero, should never be allowed to happen to a citizen of the United State…',
#        ' Despite reports to the contrary, Sweden is paying heavily for its decision not to lockdown. As of today, 2462 people h…',
#        ' Lyin’ Brian Williams of MSDNC! ',
#        ' I must admit that Lyin’ Brian Williams is, while dumber than hell, quite a bit smarter than Fake News  “anchorman”…',
#        'FAKE NEWS! ', 'Great! ',
#        ' . doesn’t want to speak about their persecution of General Michael Flynn &amp; why they got the story so wrong. They,…',
#        'DIRTY COP JAMES COMEY GOT CAUGHT!',
#        " DEMOCRATS DIDN'T EXPECT THIS - Washington Post Poll: Hispanics Are the Strongest Opponents of Immigration …",
#        ' The economy is going to do so well this Summer and make Trump look so good that Democrats will accuse HIM of hyping COVID-…',
#        ' Ryan Helfenbein: Reopening the Economy Is Not Partisan, It’s Necessary ',
#        " Hey Democrats,\n\nAren't you concerned Bernie voters didn't show up in the primaries?",
#        ' Imagine having your life and reputation ruined by rogue US govt. officials. Then years later when the plot finally come…',
#        ' The only person on the planet who thinks Comey is a decent human being is Comey. We now know what a corrupt piece of garbage…',
#        ' #SlowWalker - BREAKING: Former FBI General Counsel James Baker Has Flipped! Durham is Building Conspiracy Case on All of T…',
#        ' Flynn Attorney Sidney Powell: The Documents That Are Yet to Be Released "Are Even More Stunning" (VIDEO) …',
#        ' General Flynn Posts Triumphant Tweet Following Release of Handwritten FBI Notes Revealing He Was Framed …',
#        " I have yet to read a single Democrat leader OUTRAGED by the explosive new Flynn revelations.\n\nShouldn't they be?\n\nShouldn'…",
#        ' Turns out the only ones who colluded with Russians were Hillary Clinton’s campaign &amp; the DNC.\n\nTime for Comey’s crooked c…',
#        'Plus many! ',
#        ' THANK YOU to all of the conservative media figures who doggedly reported on the grotesque attack on General Flynn for years.…',
#        ' Not only should general Flynn’s charges be dropped immediately but the treasonous actors who set him up should be in ja…',
#        'Really? Have you looked at the numbers lately! ',
#        'FAKE POLLING, just like 2016 (but worse)!',
#        'What happened to General Michael Flynn, a war hero, should never be allowed to happen to a citizen of the United States again!',
#        'Does anybody really believe that Roger Stone, a man whose house was raided early in the morning by 29 gun toting FBI Agents (with Fake News  closely in toe), was treated fairly. How about the jury forewoman with her unannounced hatred &amp; bias. Same scammers as General Flynn!',
#        'Despite reports to the contrary, Sweden is paying heavily for its decision not to lockdown. As of today, 2462 people have died there, a much higher number than the neighboring countries of Norway (207), Finland (206) or Denmark (443). The United States made the correct decision!',
#        'Lyin’ Brian Williams of MSDNC! ',
#        'I must admit that Lyin’ Brian Williams is, while dumber than hell, quite a bit smarter than Fake News  “anchorman” Don Lemon, the “dumbest man on television”. Then you have Psycho Joe “What Ever Happened To Your Girlfriend?” Scarborough, another of the low I.Q. individuals!',
#        'Lyin’ Brian Williams of MSDNC, a Concast Scam Company, wouldn’t know the truth if it was nailed to his wooden forehead. Remember when he lied about his bravery in a helicopter? Totally made up story. He’s a true dummy who was thrown off Network News like a dog. Stay tuned!',
#        'Just told that Fake News  is falsely reporting that I was recently shouting at my campaign manager over made up nonsense. Actually, he is doing a great job, I never shouted at him (been with me for years, including the 2016 win), &amp; have no intention to do so. Just FAKE NEWS!',
#        '. doesn’t want to speak about their persecution of General Michael Flynn &amp; why they got the story so wrong. They, along with others, should pay a big price for what they have purposely done to this man &amp; his family. They won’t even cover the big breaking news about this scam!',
#        '', ' ',
#        'Happy Birthday to three time Olympian and five term Congressman, !',
#        ' ', '', '',
#        ' LIVE: POTUS holds a roundtable with industry executives ',
#        ' Our nation has ample supply of food—and President  is clearing the bottleneck and ensuring that our farmers…',
#        ' Brighter days are ahead for Louisiana and by working together with our federal officials, I know we will get through this…',
#        ' I again want to thank  and  for supporting the people of Louisiana during this difficult time. We had…',
#        ' "We are grateful to  for protecting our nation’s food supply," said  Pres. &amp; CEO Julie Ann…',
#        'No, I think Amash would make a wonderful candidate, especially since he is way behind in his district and has no chance of maintaining his Congressional seat. He almost always votes for the Do Nothing Dems anyway. I like him even more than Jill Stein! ',
#        'THANK YOU ! \n',
#        ' Yahoo reporter apologizes to President Trump after making false coronavirus test claim in Oval Office meeting \n…',
#        'At least they admit it. The Failing  &amp;  never correct their Fake Reporting! ',
#        ' 🚨🚨 TUNE IN NOW 🚨🚨\n\nTonight’s  Online! has two of the best —&gt;  &amp;  talking about Slee…',
#        ' WATCH: Team Trump Online with  and House GOP Leader ! #TeamTrump\n\nText TRUMP to 88022 …',
#        ' Tisa Clark, CEO Of J.D. Clark Professional Services, credits the #PaycheckProtectionProgram for allowing her to keep her wor…',
#        " As Trump campaign senior advisor  said today, Joe Biden's plan to ease sanctions on the Cuban and Venezuel…",
#        ' Joe Biden rambles and struggles for words during interview on coronavirus response ',
#        ' Joe Biden’s town hall with Hillary Clinton got off to a fantastic start\n ',
#        ' A reporter angrily insisted he was right about coronavirus testing data. In fact, he was wrong, and President Trump was r…',
#        " Joe Biden forgot he's supposed to be lying about President Trump's coronavirus response – and he actually told the truth!…",
#        " Joe Biden spent 44 years in Washington standing up FOR China.\n\nYou can't teach an old dog new tricks. …",
#        'The only reason the U.S. has reported one million cases of CoronaVirus is that our Testing is sooo much better than any other country in the World. Other countries are way behind us in Testing, and therefore show far fewer cases!',
#        'THANK YOU MICHAEL!  ',
#        ' We built the greatest economy in the world—and together, we will build it again! ',
#        ' Thank you, President , for your steadfast, unapologetic support of law enforcement during #COVID19. From DAY ONE…',
#        ' ', '',
#        ' LIVE: POTUS delivers remarks on supporting small businesses ',
#        'Thank you  and ! #AmericaStrong  ',
#        ' BREAKING: Emails show Obama FBI was out to get  and also knew McCain leaked anti- dossier; …',
#        ' A fifth to half of all coronavirus deaths have been in nursing homes: ',
#        ' Newly Declassified Documents Show John Kerry’s State Department Spread Russia Collusion Narrative ',
#        ' Newly Revealed Docs Support Flynn’s Innocence: Case Against Him Should Be Tossed ',
#        'But I love Diamond &amp; Silk, and so do millions of people! ',
#        ' 45 days ago, business leaders joined President  in the Rose Garden to help launch a new, critical partnersh…',
#        'Texas to open businesses in phases beginning Friday. Great job being done by ',
#        'Many States moving to SAFELY &amp; QUICKLY reopen!',
#        'We are doing far more, and better, Testing than any other country in the world, and yet the media does nothing but complain. No matter how good a job is done, the same as with the Ventilators, they will never say we are doing a great job, they will only viciously gripe!',
#        ' First, there is no shortage of meat destined for the grocery store shelf. \n\nIt might take stores longer than usual to resto…',
#        ' ',
#        ' Attorney General Barr’s Memo to U.S. Attorneys: \n\n“The Constitution is not suspended in times of crisis.” \n\nThe Attorney Ge…',
#        'Because Shifty is a crooked politician! ',
#        ' FAKE NEWS, THE ENEMY OF THE PEOPLE!',
#        ' There has never been, in the history of our Country, a more vicious or hostile Lamestream Media than there is right no…',
#        ' Blame the Democrats for any “lateness” in your Enhanced Unemployment Insurance. I wanted the money to be paid directly…',
#        ' So true!',
#        " President 's plan for Opening Up America Again outlined a three-phased approach based on the advice of publ…",
#        '',
#        ' "We\'re doing everything in our power to heal the sick and to gradually reopen our Nation." ',
#        ' As one American family, we grieve with those who have suffered the loss of loved ones. ',
#        ' LIVE: President  holds a news conference ',
#        'I will be having a White House Press Conference today at 5:30 P.M. Thank you!',
#        'Why should the people and taxpayers of America be bailing out poorly run states (like Illinois, as example) and cities, in all cases Democrat run and managed, when most of the other states are not looking for bailout help? I am open to discussing anything, but just asking?',
#        'FAKE NEWS, THE ENEMY OF THE PEOPLE!',
#        'There has never been, in the history of our Country, a more vicious or hostile Lamestream Media than there is right now, even in the midst of a National Emergency, the Invisible Enemy!',
#        'Blame the Democrats for any “lateness” in your Enhanced Unemployment Insurance. I wanted the money to be paid directly, they insisted it be paid by states for distribution. I told them this would happen, especially with many states which have old computers.',
#        'So true! ',
#        ' I never said the pandemic was a Hoax! Who would say such a thing? I said that the Do Nothing Democrats, together with…',
#        ' The people that know me and know the history of our Country say that I am  the hardest working President in history. I…',
#        " Sloppy Joe is trending. I wonder if it's because of this. You can tell it's a deep fake because Jill Biden isn't covering f…",
#        ' Article should have read: Trump as businessman had a passive, non-controlling/managing interest in an office building which…',
#        ' Devin Nunes-“Why is General Flynn Important? Because He Was Framed By His Own Government!!” #HumanScum  …',
#        ' Despite Democrats resistance to help small businesses, President  will get the economy going and Americ…',
#        ' Lefty holier than thou Media Matters founder David Brock, who spends millions targeting President Trump, is accused of…',
#        ' Democrats are not sending us their best\n\nor are they😜',
#        ' Here’s what serial fraudster, &amp; generational corruptocrat, Nancy Pelosi was REALLY up to when the Wuhan Virus was raging &amp; th…',
#        ' Report: FBI Knew McCain Leaked Steele Dossier, Now Blames Coronavirus For Not Releasing Documents ',
#        ' Former NSC Chief of Staff Says John Brennan Hid Evidence Putin Favored Hillary in 2016 🔥🔥🔥\n',
#        ' You’re a racist, radical communist that wants to expand government control and dependency— and you are using the plight o…',
#        ' Once again, Nancy Pelosi is lying about her needless delay.\n\nShe stood in front of her fancy refrigerator and congratula…',
#        ' Wishing you a very special birthday, . Happy Birthday! \U0001f973🎂',
#        'American citizens! We were long ahead of Dems, who were all against the BAN. ',
#        " Three failed coup attempts:\n\n1 - Russia Collusion hoax during campaign\n2 - Mueller's sham \n3 - Illegitimate impeachment…",
#        ' Breaking News: sources tell me  will be completely exonerated this week.  It was a total fraud.  A Set up.  Mo…',
#        'Great! ',
#        ' Dear God,\nThank you for answering our prayers.\nA grateful Nation\n\n#GodBlessAmerica🇺🇸 #PresidentTrump #ElectionDay …',
#        ' WATCH: Team Trump Online with , Rep. , and Rep. ! #TeamTrump\n\nText TRUMP to 88022 http…',
#        ' Remember, the Cure can’t be worse than the problem itself. Be careful, be safe, use common sense!',
#        ' From Day 1, Gretchen Whitmer has been too focused on politics.\n\nCase in point: She just claimed she is “not getting invo…',
#        'They are one of the worst in the “news” business. Total slime balls! ',
#        'They asked me to be at West Point on June 13th., &amp; I will be there! ',
#        ' "All of American society is engaged and mobilized in the war against the invisible enemy. While we must remain vigilant, it…',
#        ' We’re seeing enthusiasm like this all across the country. Thank you to all the  supporters who pitched i…'],
#       dtype='<U284')

# %%
for tweet in clean_tw:
    custom_tweet_set = bag_of_words(tweet)
    print (classifier.classify(custom_tweet_set))
# Out:
# pos
# neg
# pos
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# pos
# neg
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# neg
# neg
# pos
# neg
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# neg
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# neg
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# neg
# neg
# neg
# pos
# pos
# neg
# pos
# neg
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# neg
# neg
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# neg
# pos
# pos
